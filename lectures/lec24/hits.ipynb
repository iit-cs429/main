# %% [markdown]
# # CS 429: Information Retrieval
# <br>
#
# ## Lecture 26: HITS
#
# <br>
#
# ### Dr. Aron Culotta
# ### Illinois Institute of Technology
# ### Spring 2015

# %% [markdown]
# The **Hubs and Authorities** algorithm is a simple procedure to assign each page two scores:
#
# - **hub score:** how likely is this page to be a directory?
# - **authority score:** how likely is this page to be a trustworthy resource on a topic?

# %% [markdown]
# Let $F_u$ be *forward* links (going out from $u$).
#
# Let $B_u$ be *back* links (going in to $u$).
#
# $$ \begin{align}
# h(u) = \sum_{v \in F_u} a(v)\\
# a(u) = \sum_{v \in B_u} h(v)\\
# \end{align}$$
#
# In words:
#
# - The hub score for $u$ is the sum of the authority scores for all pages linked from $u$.
# - The authority score for $u$ is the sum of the hub scores for all pages linking to $u$.

# %% [markdown]
# As for PageRank, we can compute these iteratively until convergence:
#
# 1. Initialize all hub/authority scores to 1.0
# 2. Loop until convergence
#   1. update authority scores
#   2. update hub scores

# %% [markdown]
# Let's try this out on some real data:

# %%
# See http://stackoverflow.com/questions/1657570/google-search-from-a-python-app
import json
import urllib.parse, urllib.request
from google import search  # pip install google

def clean_url(url):
    if url[-1] == '/':
        return url[:-1]
    else:
        return url
    
def search_google(query_str, limit):
    return set([clean_url(u) for u in search(query_str, stop=limit)][:limit])

# %%
# Get some search results.
urls = search_google('chicago technical universities', 10)
print('top', len(urls), 'results:\n', '\n'.join(urls))
# Out:
# top 10 results:
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# http://engineering.uic.edu/COE/UndergraduatePrograms
# http://admissions.iit.edu/graduate
# http://www.engineering.uic.edu
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
# http://ortchicagotech.edu

# %%
def get_domain(s):
    return '_'.join(urllib.parse.urlparse(s).netloc.split('.')[-2:])
print(get_domain('http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691'))
# Out:
# rankingsandreviews_com

# %%
# Download links for each url. Store inlinks/outlinks for each page in original set.
from collections import defaultdict
import requests
import time
from bs4 import BeautifulSoup  # pip install beautifulsoup4

    
def crawl(toprocess, depth=2):
    """ Crawl pages from seed set."""
    processed = set()
    inlinks = defaultdict(lambda: set())   # url -> set of inlinks
    outlinks = defaultdict(lambda: set())  # url -> set of outlinks 

    for i in range(depth):  # depth to crawl
        toprocess -= processed
        new_urls = set()
        for url in toprocess:
            print('url=', url)
            domain = get_domain(url)
            text = ''
            try:
                time.sleep(.2)
                text = requests.get(url).text
            except:
                print('CANNOT FETCH %s' % url)
                continue
            soup = BeautifulSoup(text)
            processed.add(url)
            links = set([clean_url(a['href']) for a in soup.findAll('a') if a.get('href') and
                                                                            a['href'][:5] == 'http:' and
                                                                            get_domain(a['href']) != domain])
            print('found %d links' % len(links))
            outlinks[url] = links
            for link in links:
                inlinks[link].add(url)
            # Add links to be processed
            links = [l for l in links if l not in processed and l not in toprocess][:20]
            new_urls |= set(links)
        toprocess = new_urls
    return inlinks, outlinks
    
inlinks, outlinks = crawl(urls)
# Out:
# url= https://web.iit.edu/about/academic-programs
# /Users/awculott/.local/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# found 6 links
# url= http://web.iit.edu
# found 7 links
# url= https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# found 4 links
# url= http://engineering.uic.edu/COE/UndergraduatePrograms
# found 4 links
# url= http://admissions.iit.edu/graduate
# found 10 links
# url= http://www.engineering.uic.edu
# found 4 links
# url= http://www.iit.edu
# found 7 links
# url= https://admissions.iit.edu/undergraduate
# found 12 links
# url= http://web.iit.edu/directory
# found 13 links
# url= http://ortchicagotech.edu
# found 5 links
# url= http://www.youtube.com/user/IITToday
# found 1 links
# url= http://nces.ed.gov/collegenavigator/?s=IL
# found 3 links
# url= http://myillinoistech.tumblr.com
# found 10 links
# url= http://www.pinterest.com/ortchicago
# found 2 links
# url= http://www.bexleyseabury.edu/seabury-in-chicago
# found 4 links
# url= http://www.flickr.com/photos/iitugadmission/sets
# found 1 links
# url= http://www.youvisit.com
# found 4 links
# url= http://www.kentlaw.edu/students/organizations.html
# found 17 links
# url= http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# found 7 links
# url= http://issuu.com/coeuic/docs/your_path_to_uicengineering/0
# found 0 links
# url= http://wildwestonlineproductions.com
# found 4 links
# url= http://twitter.com/UICEngineering
# found 1 links
# url= http://www.facebook.com/IITGraduateRecruitment
# found 0 links
# url= http://twitter.com/IITUGadmission
# found 1 links
# url= http://www.youtube.com/user/UICengineering
# found 1 links
# url= http://galvinlibrary.wordpress.com
# found 11 links
# url= http://blogs.kentlaw.edu/faculty
# found 44 links
# url= http://ortchicago.blogspot.com
# found 10 links
# url= http://www.facebook.com/IITScarletHawks
# found 0 links
# url= http://resu.edu/academics
# found 8 links
# url= http://www.universitytechnologypark.com
# found 4 links
# url= http://www.iitri.org
# found 1 links
# url= http://www.iitmicrogrid.net
# found 0 links
# url= http://beonair.com/about
# found 0 links
# url= http://www.kentlaw.edu
# found 21 links
# url= http://academicresourcecenter.blogspot.com
# found 9 links
# url= http://betbonus365.webs.com
# CANNOT FETCH http://betbonus365.webs.com
# url= http://www.flickr.com/photos/uic_engineering/sets
# found 1 links
# url= http://blogs.kentlaw.edu
# found 44 links
# url= http://www.kentlaw.edu/record
# found 2 links
# url= http://www.flickr.com/photos/49476807@N04/sets
# found 1 links
# url= http://www.illinoistechathletics.com
# found 17 links
# url= http://e.weibo.com/iitgraduateadmission
# found 0 links
# url= http://www.linkedin.com/company/chicago-ort-technical-institute
# found 0 links
# url= http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
# found 11 links

# %%
urls = set(list(inlinks.keys())) | set(list(outlinks.keys()))
print('%d total urls' % len(urls))
# Out:
# 215 total urls

# %%
# Print outlinks.
for url in outlinks:
    if len(outlinks[url]) > 0:
        print('\n', url, '->\n', '\n'.join(outlinks[url]))
# Out:
#  http://www.youtube.com/user/IITToday ->
#  http://www.iit.edu
#
#  http://www.pinterest.com/ortchicago ->
#  http://enable-javascript.com
# http://ortchicagotech.edu
#
#  http://www.bexleyseabury.edu/seabury-in-chicago ->
#  http://www.twitter.com/bexleyseabury
# http://www.facebook.com/bexleyseabury
# http://mail.google.com/a/bexleyseabury.edu
# http://www.anglicantheologicalreview.org
#
#  http://www.flickr.com/photos/iitugadmission/sets ->
#  http://flickr.tumblr.com
#
#  http://www.kentlaw.edu ->
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4528&information_id=7192&type=&rss=rss
# http://www.facebook.com/ChicagoKentLaw
# http://www.iit.edu
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4153&information_id=6391&type=&rss=rss
# http://instagram.com/chicagokentlaw
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4518&information_id=7172&type=&rss=rss
# http://www.iit.edu/about/department_sites.shtml
# http://www.iit.edu/cdr
# http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014
# http://www.oyez.org
# http://www.alumni.kentlaw.iit.edu/give
# http://www.iit.edu/directory/shuttlebus.html
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393
# http://blogs.kentlaw.iit.edu
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4557&information_id=7250&type=&rss=rss
# http://calendar.kentlaw.iit.edu
# http://twitter.com/ChicagoKentLaw
# http://www.youtube.com/ChicagoKentLaw
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4465&information_id=7062&type=&rss=rss
# http://www.dtc.bkstore.com
#
#  http://www.youvisit.com ->
#  http://pinterest.com/YouVisit
# http://instagram.com/youvisit
# http://www.facebook.com/youvisit
# http://www.twitter.com/You_Visit
#
#  http://twitter.com/UICEngineering ->
#  http://t.co/fTZJPTLz7Z
#
#  http://galvinlibrary.wordpress.com ->
#  http://www.pbs.org/latino-americans/en/watch-videos/#2365003928
# http://web.iit.edu/about/main-campus-map
# http://www.pbs.org/latino-americans/en/watch-videos/#2365075996
# http://chronicle.com/wiredcampus
# http://www.theguardian.com/books/booksblog/2013/dec/17/forget-selfies-we-want-to-see-your-shelfies
# http://www.iit.edu/publications/iittoday/index.php
# http://www.pbs.org/latino-americans/en/watch-videos/#2365076196
# http://library.iit.edu
# http://twitter.com/GalvinLibrary
# http://acrlblog.org
# http://gl.iit.edu/students/fun/anime
#
#  http://www.flickr.com/photos/uic_engineering/sets ->
#  http://flickr.tumblr.com
#
#  http://ortchicago.blogspot.com ->
#  http://bit.ly/1GNDUt5
# http://bit.ly/1HxWUGW
# http://bit.ly/20CpSkT
# http://bit.ly/1MczHwe
# http://www.istockphoto.com/googleimages.php?id=5848437&platform=blogger&langregion=en
# http://bit.ly/1M0cZcM
# http://bit.ly/1iFYwrE
# http://bit.ly/1O1XMIV
# http://www.linkedin.com/company/chicago-ort-technical-institute
# http://bit.ly/1iOdCLQ
#
#  http://web.iit.edu ->
#  http://www.universitytechnologypark.com
# http://www.iitri.org
# http://www.iitmicrogrid.net
# http://www.youvisit.com
# http://www.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.illinoistechathletics.com
#
#  http://www.universitytechnologypark.com ->
#  http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775
# http://www.aurp.net
# http://www.nbia.org
# http://www.aurp.net/aurp-awards-of-excellence
#
#  http://www.iitri.org ->
#  http://www.iubenda.com/privacy-policy/264605
#
#  http://engineering.uic.edu/COE/UndergraduatePrograms ->
#  http://twitter.com/UICEngineering
# http://issuu.com/coeuic/docs/your_path_to_uicengineering/0
# http://www.youtube.com/user/UICengineering
# http://www.flickr.com/photos/uic_engineering/sets
#
#  http://academicresourcecenter.blogspot.com ->
#  http://iit.edu/arc/employment_at_arc
# http://iit.edu/arc
# http://www.studygs.net/tsttak1.htm
# http://iit.edu/arc/employment_at_arc.shtml
# http://www.huffingtonpost.com/dr-michael-j-breus/the-freshman-8-and-your-g_b_703155.html
# http://goo.gl/DRhFh
# http://iit.edu/arc/about
# http://collegelife.about.com/od/cocurricularlife/a/GoodNewYearsResolutions.htm
# http://goo.gl/8hczAS
#
#  http://www.kentlaw.edu/record ->
#  http://www.kentlaw.iit.edu/legal-clinics
# http://www.kentlaw.iit.edu/academics/jd-program/practical-skills-training/externships
#
#  http://www.illinoistechathletics.com ->
#  http://web.iit.edu
# http://www.d3sports.com/landing/index
# http://web.iit.edu/about/campus-locations
# http://admissions.iit.edu/undergraduate/programs
# http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student
# http://admissions.iit.edu/undergraduate/visit
# http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student
# http://www.prestosports.com
# http://www.adidas.com/us
# http://wcsphoto.zenfolio.com/f417637883
# http://www.theuscaa.com/landing/index
# http://www.collegecostcalculator.org/IIT
# http://admissions.iit.edu/undergraduate/apply
# http://www.ncaa.com
# http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education
# http://admissions.iit.edu/undergraduate
# http://www.mlc-mwlc.org/landing/index
#
#  http://blogs.kentlaw.edu/faculty ->
#  http://blogs.kentlaw.iit.edu/staff-departments
# http://blogs.kentlaw.iit.edu/facultynews
# http://www.facebook.com/ChicagoKentLaw
# http://blogs.kentlaw.iit.edu/faculty/feed
# http://blogs.kentlaw.iit.edu/facultynews/feed
# http://blogs.kentlaw.iit.edu/facultynews/faculty-activities-january-2016
# http://blogs.kentlaw.iit.edu/islat/feed
# http://www.kentlaw.iit.edu
# http://blogs.kentlaw.iit.edu
# http://nahmodlaw.com/2016/02/11/mullinex-v-luna-a-supreme-court-qualified-immunity-excessive-forcehigh-speed-police-chase-decision
# http://nahmodlaw.com/2016/02/22/get-over-it-justice-scalia-and-bush-v-gore-roe-v-wade-and-obergefell
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-15-2016
# http://twitter.com/ChicagoKentLaw
# http://nahmodlaw.com
# http://legislate-ck.blogspot.com
# http://blogs.kentlaw.iit.edu/islat/2015/03/16/the-thin-red-line
# http://blogs.kentlaw.iit.edu/iscotus
# http://blogs.kentlaw.iit.edu/islat
# http://blogs.kentlaw.iit.edu/islat/2015/02/02/a-white-house-invitation-to-launch-precision-medicine
# http://www.linkedin.com/groupInvitation?gid=71469&sharedKey=2839B80CA393
# http://www.discwebsite.org
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-1-2016
# http://blogs.kentlaw.iit.edu/faculty/2016/04/08/gerber-antitrust-article-award
# http://blogs.kentlaw.iit.edu/iscotus/feed
# http://blogs.kentlaw.iit.edu/facultynews/research-in-progress-january-2016
# http://blogs.kentlaw.iit.edu/facultynews/publications-january-2016
# http://studentorgs.kentlaw.iit.edu/home/website-updates
# http://nahmodlaw.com/2016/02/12/federal-attorneys-fees-statute-means-what-scotus-says-it-means-slapping-down-the-idaho-supreme-court
# http://blogs.kentlaw.iit.edu/iscotus/what-happened-in-evenwel
# http://www.huffingtonpost.com/bernadette-atuahene
# http://www.elsblog.org
# http://nahmodlaw.com/2016/03/24/certiorari-granted-in-important-section-1983-malicious-prosecution-case-manuel-v-city-of-joliet
# http://blogs.kentlaw.iit.edu/faculty/2016/03/04/lee-discusses-privacy-at-uofc
# http://blogs.kentlaw.iit.edu/faculty
# http://www.nahmodlaw.com/feed
# http://blogs.kentlaw.iit.edu/islat/2015/04/14/when-your-car-spies-on-you
# http://blogs.kentlaw.iit.edu/islat/2015/03/02/isps-as-public-utilities
# http://nahmodlaw.com/2016/01/04/my-class-on-race-dred-scott-and-korematsu-audio
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-25-2016
# http://www.youtube.com/ChicagoKentLaw
# http://worldtradelaw.typepad.com/ielpblog
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-18-2016
# http://blogs.kentlaw.iit.edu/islat/2014/12/16/chicago-profiteering-from-irregular-yellow-light-timing
# http://blogs.kentlaw.iit.edu/faculty/2016/03/16/rosado-marzan-knowledgewharton-bbc-newshour
#
#  http://web.iit.edu/directory ->
#  http://www.universitytechnologypark.com
# http://www.iitri.org
# http://www.iitmicrogrid.net
# http://www.kentlaw.edu
# http://academicresourcecenter.blogspot.com
# http://www.kentlaw.edu/students/organizations.html
# http://blogs.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.flickr.com/photos/49476807@N04/sets
# http://www.kentlaw.edu/record
# http://www.illinoistechathletics.com
# http://galvinlibrary.wordpress.com
# http://blogs.kentlaw.edu/faculty
#
#  https://web.iit.edu/about/academic-programs ->
#  http://www.universitytechnologypark.com
# http://www.iitri.org
# http://www.iitmicrogrid.net
# http://www.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.illinoistechathletics.com
#
#  http://nces.ed.gov/collegenavigator/?s=IL ->
#  http://fedstats.sites.usa.gov
# http://www.bls.gov/oco
# http://www.childstats.gov
#
#  http://myillinoistech.tumblr.com ->
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142410510351%2Fiit-bot-outstanding-undergraduate-teaching-award&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F141107965701%2Fempty-hallways-regram-from-ajaypalaniswamy-at&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F141629605071%2Fcloudy-day-in-chicago-regram-from-lavdizymberi&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142525463186%2Fshout-out-to-everyone-who-joined-us-for&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142814119241%2Fjohn-w-rowe-excellence-in-teaching-award-jialing&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142045013856%2Fyou-can-really-tell-when-the-architects-come-to&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F140826613986%2Fregram-from-carlienecombr-iit-illinoistech&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142865008796%2Fperfect-capture-from-the-color-run-yesterday&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F140507071436%2Fthe-calm-before-the-scarlet-hawk-storm&t=My%20Illinois%20Tech
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142643364801%2Fcongratulation-greeks-to-a-successful-greek-week&t=My%20Illinois%20Tech
#
#  http://www.kentlaw.edu/students/organizations.html ->
#  http://www.facebook.com/ChicagoKentLaw
# http://www.iit.edu/about/department_sites.shtml
# http://instagram.com/chicagokentlaw
# http://www.iit.edu/cdr
# http://studentorgs.kentlaw.iit.edu/sba
# http://www.oyez.org
# http://www.alumni.kentlaw.iit.edu/give
# http://www.iit.edu/directory/shuttlebus.html
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393
# http://blogs.kentlaw.iit.edu
# http://calendar.kentlaw.iit.edu
# http://twitter.com/ChicagoKentLaw
# http://www.youtube.com/ChicagoKentLaw
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A
# http://www.kentlaw.iit.edu/x1235.xml
# http://www.iit.edu
# http://www.dtc.bkstore.com
#
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 ->
#  http://www.thecollegejuice.com
# http://www.barnesandnoble.com/include/copyright.asp
# http://www.facebook.com/IITbookstore
# http://forms.bncollegemail.com/email/form2.htm
# http://www.facultyenlight.com/?storeNbr=296
# http://thecollegejuice.com
# http://www.bncollegejobs.com
#
#  http://wildwestonlineproductions.com ->
#  http://www.linkedin.com/company/wild-west-online-productions
# http://twitter.com/wildwestonline
# http://denzeldesigns.org
# http://www.youtube.com/wildwestwebvideo
#
#  http://twitter.com/IITUGadmission ->
#  http://t.co/qPTHzOpFw2
#
#  http://www.youtube.com/user/UICengineering ->
#  http://www.engr.uic.edu
#
#  https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago ->
#  http://beonair.com/about
# http://nces.ed.gov/collegenavigator/?s=IL
# http://resu.edu/academics
# http://www.bexleyseabury.edu/seabury-in-chicago
#
#  http://ortchicagotech.edu ->
#  http://ortchicago.blogspot.com
# http://www.linkedin.com/company/chicago-ort-technical-institute
# http://betbonus365.webs.com
# http://wildwestonlineproductions.com
# http://www.pinterest.com/ortchicago
#
#  http://www.iit.edu ->
#  http://www.universitytechnologypark.com
# http://www.iitri.org
# http://www.iitmicrogrid.net
# http://www.youvisit.com
# http://www.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.illinoistechathletics.com
#
#  http://resu.edu/academics ->
#  http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2016/03/2015-17-Academic-Calendar-3.21.16.pdf
# http://www.linkedin.com/groups?gid=4818331&mostPopular=&trk=tyah
# http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2015/06/2015-17-Academic-Calendar-5.1.15.pdf
# http://resustore.com
# http://tcc.noellevitz.com/(S(wh1yd0kkfpibjut4exhbtt4e))/Resurrection%20University/Bachelors
# http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2016/02/Directions-to-ResU1.pdf
# http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2015/02/Reflections-Fall-20141.pdf
# http://bookstore.mbsdirect.net/resu.htm
#
#  http://blogs.kentlaw.edu ->
#  http://blogs.kentlaw.iit.edu/staff-departments
# http://blogs.kentlaw.iit.edu/facultynews
# http://www.facebook.com/ChicagoKentLaw
# http://blogs.kentlaw.iit.edu/faculty/feed
# http://blogs.kentlaw.iit.edu/facultynews/feed
# http://blogs.kentlaw.iit.edu/facultynews/faculty-activities-january-2016
# http://blogs.kentlaw.iit.edu/islat/feed
# http://www.kentlaw.iit.edu
# http://blogs.kentlaw.iit.edu
# http://nahmodlaw.com/2016/02/11/mullinex-v-luna-a-supreme-court-qualified-immunity-excessive-forcehigh-speed-police-chase-decision
# http://nahmodlaw.com/2016/02/22/get-over-it-justice-scalia-and-bush-v-gore-roe-v-wade-and-obergefell
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-15-2016
# http://twitter.com/ChicagoKentLaw
# http://nahmodlaw.com
# http://legislate-ck.blogspot.com
# http://blogs.kentlaw.iit.edu/islat/2015/03/16/the-thin-red-line
# http://blogs.kentlaw.iit.edu/iscotus
# http://blogs.kentlaw.iit.edu/islat
# http://blogs.kentlaw.iit.edu/islat/2015/02/02/a-white-house-invitation-to-launch-precision-medicine
# http://www.linkedin.com/groupInvitation?gid=71469&sharedKey=2839B80CA393
# http://www.discwebsite.org
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-1-2016
# http://blogs.kentlaw.iit.edu/faculty/2016/04/08/gerber-antitrust-article-award
# http://blogs.kentlaw.iit.edu/iscotus/feed
# http://blogs.kentlaw.iit.edu/facultynews/research-in-progress-january-2016
# http://blogs.kentlaw.iit.edu/facultynews/publications-january-2016
# http://studentorgs.kentlaw.iit.edu/home/website-updates
# http://nahmodlaw.com/2016/02/12/federal-attorneys-fees-statute-means-what-scotus-says-it-means-slapping-down-the-idaho-supreme-court
# http://blogs.kentlaw.iit.edu/iscotus/what-happened-in-evenwel
# http://www.huffingtonpost.com/bernadette-atuahene
# http://www.elsblog.org
# http://nahmodlaw.com/2016/03/24/certiorari-granted-in-important-section-1983-malicious-prosecution-case-manuel-v-city-of-joliet
# http://blogs.kentlaw.iit.edu/faculty/2016/03/04/lee-discusses-privacy-at-uofc
# http://blogs.kentlaw.iit.edu/faculty
# http://www.nahmodlaw.com/feed
# http://blogs.kentlaw.iit.edu/islat/2015/04/14/when-your-car-spies-on-you
# http://blogs.kentlaw.iit.edu/islat/2015/03/02/isps-as-public-utilities
# http://nahmodlaw.com/2016/01/04/my-class-on-race-dred-scott-and-korematsu-audio
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-25-2016
# http://www.youtube.com/ChicagoKentLaw
# http://worldtradelaw.typepad.com/ielpblog
# http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-18-2016
# http://blogs.kentlaw.iit.edu/islat/2014/12/16/chicago-profiteering-from-irregular-yellow-light-timing
# http://blogs.kentlaw.iit.edu/faculty/2016/03/16/rosado-marzan-knowledgewharton-bbc-newshour
#
#  http://admissions.iit.edu/graduate ->
#  http://www.youtube.com/user/IITToday
# http://www.universitytechnologypark.com
# http://www.iitri.org
# http://www.iitmicrogrid.net
# http://www.youvisit.com
# http://www.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.illinoistechathletics.com
# http://e.weibo.com/iitgraduateadmission
# http://www.facebook.com/IITGraduateRecruitment
#
#  http://www.engineering.uic.edu ->
#  http://twitter.com/UICEngineering
# http://www.flickr.com/photos/uic_engineering/sets
# http://www.youtube.com/user/UICengineering
# http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation ->
#  http://feeds.huffingtonpost.com/c/35496/f/677051/s/4eec3fb2/sc/13/l/0L0Shuffingtonpost0N0C20A160C0A40C130Cchicago0Epolice0Eaccountability0Ereport0In0I96850A440Bhtml0Dutm0Ihp0Iref0Fchicago0Gir0FChicago/story01.htm
# http://feeds.feedburner.com/ChicagoTonight
# http://www.huffingtonpost.com/2016/04/15/minimum-wage-protests_n_9699048.html?utm_hp_ref=chicago&ir=Chicago
# http://www.wfmt.com
# http://chicagotonight.disqus.com/?url=http%3A%2F%2Fchicagotonight.wttw.com%2F2016%2F02%2F24%2Fapple-vs-fbi-should-privacy-rights-outrank-federal-investigation
# http://polldaddy.com/poll/9322709
# http://www.huffingtonpost.com/2016/04/13/dennis-hastert-sentencing-lies_n_9697304.html?utm_hp_ref=chicago&ir=Chicago
# http://www.apple.com/customer-letter
# http://pbskids.org/games/index.html
# http://www.huffingtonpost.com/robert-koehler/creating-resilient-commun_b_9696268.html?utm_hp_ref=chicago&ir=Chicago
# http://feeds.huffingtonpost.com/c/35496/f/677051/s/4eec255c/sc/26/l/0L0Shuffingtonpost0N0Calexandra0Estarkovich0Cspringtime0Ein0Echicago0Ebuc0Ib0I9670A2760Bhtml0Dutm0Ihp0Iref0Fchicago0Gir0FChicago/story01.htm
#
#  https://admissions.iit.edu/undergraduate ->
#  http://www.facebook.com/IITScarletHawks
# http://www.youtube.com/user/IITToday
# http://www.universitytechnologypark.com
# http://www.iitri.org
# http://myillinoistech.tumblr.com
# http://www.flickr.com/photos/iitugadmission/sets
# http://www.iitmicrogrid.net
# http://www.youvisit.com
# http://www.kentlaw.edu
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.illinoistechathletics.com
# http://twitter.com/IITUGadmission
#
#  http://www.flickr.com/photos/49476807@N04/sets ->
#  http://flickr.tumblr.com

# %%
for url in outlinks:
    print(url, len(outlinks[url]))
# Out:
# http://www.youtube.com/user/IITToday 1
# http://www.pinterest.com/ortchicago 2
# http://www.bexleyseabury.edu/seabury-in-chicago 4
# http://www.flickr.com/photos/iitugadmission/sets 1
# http://www.kentlaw.edu 21
# http://www.youvisit.com 4
# http://twitter.com/UICEngineering 1
# http://galvinlibrary.wordpress.com 11
# http://www.flickr.com/photos/uic_engineering/sets 1
# http://ortchicago.blogspot.com 10
# http://web.iit.edu 7
# http://www.facebook.com/IITScarletHawks 0
# http://www.universitytechnologypark.com 4
# http://www.iitri.org 1
# http://beonair.com/about 0
# http://engineering.uic.edu/COE/UndergraduatePrograms 4
# http://academicresourcecenter.blogspot.com 9
# http://www.kentlaw.edu/record 2
# http://www.illinoistechathletics.com 17
# http://www.linkedin.com/company/chicago-ort-technical-institute 0
# http://blogs.kentlaw.edu/faculty 44
# http://web.iit.edu/directory 13
# https://web.iit.edu/about/academic-programs 6
# http://nces.ed.gov/collegenavigator/?s=IL 3
# http://myillinoistech.tumblr.com 10
# http://www.kentlaw.edu/students/organizations.html 17
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 7
# http://issuu.com/coeuic/docs/your_path_to_uicengineering/0 0
# http://wildwestonlineproductions.com 4
# http://twitter.com/IITUGadmission 1
# http://www.facebook.com/IITGraduateRecruitment 0
# http://www.youtube.com/user/UICengineering 1
# https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago 4
# http://ortchicagotech.edu 5
# http://www.iit.edu 7
# http://resu.edu/academics 8
# http://www.iitmicrogrid.net 0
# http://blogs.kentlaw.edu 44
# http://admissions.iit.edu/graduate 10
# http://e.weibo.com/iitgraduateadmission 0
# http://www.engineering.uic.edu 4
# http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation 11
# https://admissions.iit.edu/undergraduate 12
# http://www.flickr.com/photos/49476807@N04/sets 1

# %%
# Print inlinks
for url in inlinks:
    if len(inlinks[url]) > 0:
        print('\n', url, '<-\n', '\n'.join(inlinks[url]))
# Out:
#  http://www.pinterest.com/ortchicago <-
#  http://ortchicagotech.edu
#
#  http://www.bexleyseabury.edu/seabury-in-chicago <-
#  https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
#  http://www.flickr.com/photos/iitugadmission/sets <-
#  https://admissions.iit.edu/undergraduate
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142045013856%2Fyou-can-really-tell-when-the-architects-come-to&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://www.prestosports.com <-
#  http://www.illinoistechathletics.com
#
#  http://www.kentlaw.iit.edu/academics/jd-program/practical-skills-training/externships <-
#  http://www.kentlaw.edu/record
#
#  http://t.co/fTZJPTLz7Z <-
#  http://twitter.com/UICEngineering
#
#  http://www.youtube.com/wildwestwebvideo <-
#  http://wildwestonlineproductions.com
#
#  http://www.facebook.com/bexleyseabury <-
#  http://www.bexleyseabury.edu/seabury-in-chicago
#
#  http://www.bls.gov/oco <-
#  http://nces.ed.gov/collegenavigator/?s=IL
#
#  http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2016/03/2015-17-Academic-Calendar-3.21.16.pdf <-
#  http://resu.edu/academics
#
#  http://blogs.kentlaw.iit.edu/facultynews/feed <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu/islat/2015/03/16/the-thin-red-line <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.studygs.net/tsttak1.htm <-
#  http://academicresourcecenter.blogspot.com
#
#  http://beonair.com/about <-
#  https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
#  http://blogs.kentlaw.iit.edu/iscotus <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://academicresourcecenter.blogspot.com <-
#  http://web.iit.edu/directory
#
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4557&information_id=7250&type=&rss=rss <-
#  http://www.kentlaw.edu
#
#  http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2015/02/Reflections-Fall-20141.pdf <-
#  http://resu.edu/academics
#
#  http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393 <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://blogs.kentlaw.iit.edu/facultynews/faculty-activities-january-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.pbs.org/latino-americans/en/watch-videos/#2365076196 <-
#  http://galvinlibrary.wordpress.com
#
#  http://iit.edu/arc/about <-
#  http://academicresourcecenter.blogspot.com
#
#  http://chronicle.com/wiredcampus <-
#  http://galvinlibrary.wordpress.com
#
#  http://www.pbs.org/latino-americans/en/watch-videos/#2365075996 <-
#  http://galvinlibrary.wordpress.com
#
#  http://www.discwebsite.org <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.barnesandnoble.com/include/copyright.asp <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://www.facebook.com/IITbookstore <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://web.iit.edu/about/campus-locations <-
#  http://www.illinoistechathletics.com
#
#  http://bit.ly/1M0cZcM <-
#  http://ortchicago.blogspot.com
#
#  http://www.kentlaw.edu/students/organizations.html <-
#  http://web.iit.edu/directory
#
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://issuu.com/coeuic/docs/your_path_to_uicengineering/0 <-
#  http://engineering.uic.edu/COE/UndergraduatePrograms
#
#  http://www.iit.edu/publications/iittoday/index.php <-
#  http://galvinlibrary.wordpress.com
#
#  http://www.facebook.com/youvisit <-
#  http://www.youvisit.com
#
#  http://nahmodlaw.com/2016/02/12/federal-attorneys-fees-statute-means-what-scotus-says-it-means-slapping-down-the-idaho-supreme-court <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.facebook.com/IITGraduateRecruitment <-
#  http://admissions.iit.edu/graduate
#
#  http://goo.gl/8hczAS <-
#  http://academicresourcecenter.blogspot.com
#
#  http://feeds.huffingtonpost.com/c/35496/f/677051/s/4eec3fb2/sc/13/l/0L0Shuffingtonpost0N0C20A160C0A40C130Cchicago0Epolice0Eaccountability0Ereport0In0I96850A440Bhtml0Dutm0Ihp0Iref0Fchicago0Gir0FChicago/story01.htm <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://bit.ly/20CpSkT <-
#  http://ortchicago.blogspot.com
#
#  http://blogs.kentlaw.iit.edu/islat/2015/04/14/when-your-car-spies-on-you <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4518&information_id=7172&type=&rss=rss <-
#  http://www.kentlaw.edu
#
#  http://www.nahmodlaw.com/feed <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://pbskids.org/games/index.html <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://e.weibo.com/iitgraduateadmission <-
#  http://admissions.iit.edu/graduate
#
#  http://wcsphoto.zenfolio.com/f417637883 <-
#  http://www.illinoistechathletics.com
#
#  http://www.adidas.com/us <-
#  http://www.illinoistechathletics.com
#
#  http://blogs.kentlaw.iit.edu/islat/2014/12/16/chicago-profiteering-from-irregular-yellow-light-timing <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.iit.edu/cdr <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://www.flickr.com/photos/49476807@N04/sets <-
#  http://web.iit.edu/directory
#
#  http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775 <-
#  http://www.universitytechnologypark.com
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142525463186%2Fshout-out-to-everyone-who-joined-us-for&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://www.facebook.com/ChicagoKentLaw <-
#  http://blogs.kentlaw.edu
# http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu/faculty/feed <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://resustore.com <-
#  http://resu.edu/academics
#
#  http://www.facultyenlight.com/?storeNbr=296 <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://www.d3sports.com/landing/index <-
#  http://www.illinoistechathletics.com
#
#  http://www.kentlaw.iit.edu <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu <-
#  http://blogs.kentlaw.edu
# http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
# http://blogs.kentlaw.edu/faculty
#
#  http://www.theuscaa.com/landing/index <-
#  http://www.illinoistechathletics.com
#
#  http://denzeldesigns.org <-
#  http://wildwestonlineproductions.com
#
#  http://www.pbs.org/latino-americans/en/watch-videos/#2365003928 <-
#  http://galvinlibrary.wordpress.com
#
#  http://twitter.com/UICEngineering <-
#  http://www.engineering.uic.edu
# http://engineering.uic.edu/COE/UndergraduatePrograms
#
#  http://www.anglicantheologicalreview.org <-
#  http://www.bexleyseabury.edu/seabury-in-chicago
#
#  http://ortchicago.blogspot.com <-
#  http://ortchicagotech.edu
#
#  http://web.iit.edu <-
#  http://www.illinoistechathletics.com
#
#  http://bit.ly/1HxWUGW <-
#  http://ortchicago.blogspot.com
#
#  http://www.universitytechnologypark.com <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://web.iit.edu/about/main-campus-map <-
#  http://galvinlibrary.wordpress.com
#
#  http://pinterest.com/YouVisit <-
#  http://www.youvisit.com
#
#  http://www.illinoistechathletics.com <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://www.collegecostcalculator.org/IIT <-
#  http://www.illinoistechathletics.com
#
#  http://admissions.iit.edu/undergraduate/programs <-
#  http://www.illinoistechathletics.com
#
#  http://library.iit.edu <-
#  http://galvinlibrary.wordpress.com
#
#  http://www.dtc.bkstore.com <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://nces.ed.gov/collegenavigator/?s=IL <-
#  https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
#  http://iit.edu/arc <-
#  http://academicresourcecenter.blogspot.com
#
#  http://www.nbia.org <-
#  http://www.universitytechnologypark.com
#
#  http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2016/02/Directions-to-ResU1.pdf <-
#  http://resu.edu/academics
#
#  http://www.childstats.gov <-
#  http://nces.ed.gov/collegenavigator/?s=IL
#
#  http://blogs.kentlaw.iit.edu/facultynews/publications-january-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu/iscotus/what-happened-in-evenwel <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://twitter.com/IITUGadmission <-
#  https://admissions.iit.edu/undergraduate
#
#  http://www.huffingtonpost.com/bernadette-atuahene <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://acrlblog.org <-
#  http://galvinlibrary.wordpress.com
#
#  http://nahmodlaw.com/2016/03/24/certiorari-granted-in-important-section-1983-malicious-prosecution-case-manuel-v-city-of-joliet <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://bit.ly/1GNDUt5 <-
#  http://ortchicago.blogspot.com
#
#  http://www.iitri.org <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://blogs.kentlaw.iit.edu/islat/2015/03/02/isps-as-public-utilities <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://resu-cdn.s3-us-west-1.amazonaws.com/wp-content/uploads/2015/06/2015-17-Academic-Calendar-5.1.15.pdf <-
#  http://resu.edu/academics
#
#  http://bit.ly/1iFYwrE <-
#  http://ortchicago.blogspot.com
#
#  http://www.apple.com/customer-letter <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://polldaddy.com/poll/9322709 <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://goo.gl/DRhFh <-
#  http://academicresourcecenter.blogspot.com
#
#  http://www.twitter.com/You_Visit <-
#  http://www.youvisit.com
#
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation <-
#  http://www.engineering.uic.edu
#
#  http://blogs.kentlaw.iit.edu/staff-departments <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.youtube.com/user/IITToday <-
#  http://admissions.iit.edu/graduate
# https://admissions.iit.edu/undergraduate
#
#  http://iit.edu/arc/employment_at_arc <-
#  http://academicresourcecenter.blogspot.com
#
#  http://enable-javascript.com <-
#  http://www.pinterest.com/ortchicago
#
#  http://instagram.com/chicagokentlaw <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://tcc.noellevitz.com/(S(wh1yd0kkfpibjut4exhbtt4e))/Resurrection%20University/Bachelors <-
#  http://resu.edu/academics
#
#  http://www.youvisit.com <-
#  http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
#
#  http://www.alumni.kentlaw.iit.edu/give <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://www.iit.edu/directory/shuttlebus.html <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-15-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://fedstats.sites.usa.gov <-
#  http://nces.ed.gov/collegenavigator/?s=IL
#
#  http://twitter.com/ChicagoKentLaw <-
#  http://blogs.kentlaw.edu
# http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
# http://blogs.kentlaw.edu/faculty
#
#  http://nahmodlaw.com <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4465&information_id=7062&type=&rss=rss <-
#  http://www.kentlaw.edu
#
#  http://flickr.tumblr.com <-
#  http://www.flickr.com/photos/iitugadmission/sets
# http://www.flickr.com/photos/49476807@N04/sets
# http://www.flickr.com/photos/uic_engineering/sets
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F141107965701%2Fempty-hallways-regram-from-ajaypalaniswamy-at&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://www.facebook.com/IITScarletHawks <-
#  https://admissions.iit.edu/undergraduate
#
#  http://www.aurp.net/aurp-awards-of-excellence <-
#  http://www.universitytechnologypark.com
#
#  http://www.iit.edu/about/department_sites.shtml <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://www.kentlaw.edu <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://www.oyez.org <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://blogs.kentlaw.iit.edu/islat/2015/02/02/a-white-house-invitation-to-launch-precision-medicine <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student <-
#  http://www.illinoistechathletics.com
#
#  http://iit.edu/arc/employment_at_arc.shtml <-
#  http://academicresourcecenter.blogspot.com
#
#  http://www.linkedin.com/company/chicago-ort-technical-institute <-
#  http://ortchicago.blogspot.com
# http://ortchicagotech.edu
#
#  http://www.iubenda.com/privacy-policy/264605 <-
#  http://www.iitri.org
#
#  http://twitter.com/wildwestonline <-
#  http://wildwestonlineproductions.com
#
#  http://gl.iit.edu/students/fun/anime <-
#  http://galvinlibrary.wordpress.com
#
#  http://myillinoistech.tumblr.com <-
#  https://admissions.iit.edu/undergraduate
#
#  http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-april-1-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://admissions.iit.edu/undergraduate <-
#  http://www.illinoistechathletics.com
#
#  http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014 <-
#  http://www.kentlaw.edu
#
#  http://blogs.kentlaw.iit.edu/iscotus/feed <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.twitter.com/bexleyseabury <-
#  http://www.bexleyseabury.edu/seabury-in-chicago
#
#  http://www.theguardian.com/books/booksblog/2013/dec/17/forget-selfies-we-want-to-see-your-shelfies <-
#  http://galvinlibrary.wordpress.com
#
#  http://www.engr.uic.edu <-
#  http://www.youtube.com/user/UICengineering
#
#  http://studentorgs.kentlaw.iit.edu/home/website-updates <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://twitter.com/GalvinLibrary <-
#  http://galvinlibrary.wordpress.com
#
#  http://bit.ly/1O1XMIV <-
#  http://ortchicago.blogspot.com
#
#  http://www.linkedin.com/company/wild-west-online-productions <-
#  http://wildwestonlineproductions.com
#
#  http://blogs.kentlaw.edu/faculty <-
#  http://web.iit.edu/directory
#
#  http://blogs.kentlaw.iit.edu/faculty/2016/03/04/lee-discusses-privacy-at-uofc <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://feeds.feedburner.com/ChicagoTonight <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://www.iitmicrogrid.net <-
#  https://web.iit.edu/about/academic-programs
# http://web.iit.edu
# http://admissions.iit.edu/graduate
# http://www.iit.edu
# https://admissions.iit.edu/undergraduate
# http://web.iit.edu/directory
#
#  http://betbonus365.webs.com <-
#  http://ortchicagotech.edu
#
#  http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-25-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.mlc-mwlc.org/landing/index <-
#  http://www.illinoistechathletics.com
#
#  http://worldtradelaw.typepad.com/ielpblog <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.flickr.com/photos/uic_engineering/sets <-
#  http://www.engineering.uic.edu
# http://engineering.uic.edu/COE/UndergraduatePrograms
#
#  http://t.co/qPTHzOpFw2 <-
#  http://twitter.com/IITUGadmission
#
#  http://feeds.huffingtonpost.com/c/35496/f/677051/s/4eec255c/sc/26/l/0L0Shuffingtonpost0N0Calexandra0Estarkovich0Cspringtime0Ein0Echicago0Ebuc0Ib0I9670A2760Bhtml0Dutm0Ihp0Iref0Fchicago0Gir0FChicago/story01.htm <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://blogs.kentlaw.iit.edu/faculty/2016/03/16/rosado-marzan-knowledgewharton-bbc-newshour <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu/facultynews <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.iit.edu/islat/feed <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142814119241%2Fjohn-w-rowe-excellence-in-teaching-award-jialing&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://www.kentlaw.iit.edu/legal-clinics <-
#  http://www.kentlaw.edu/record
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F140826613986%2Fregram-from-carlienecombr-iit-illinoistech&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F140507071436%2Fthe-calm-before-the-scarlet-hawk-storm&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://nahmodlaw.com/2016/02/22/get-over-it-justice-scalia-and-bush-v-gore-roe-v-wade-and-obergefell <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F141629605071%2Fcloudy-day-in-chicago-regram-from-lavdizymberi&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://admissions.iit.edu/undergraduate/apply <-
#  http://www.illinoistechathletics.com
#
#  http://galvinlibrary.wordpress.com <-
#  http://web.iit.edu/directory
#
#  http://www.huffingtonpost.com/robert-koehler/creating-resilient-commun_b_9696268.html?utm_hp_ref=chicago&ir=Chicago <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://legislate-ck.blogspot.com <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://collegelife.about.com/od/cocurricularlife/a/GoodNewYearsResolutions.htm <-
#  http://academicresourcecenter.blogspot.com
#
#  http://www.wfmt.com <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://mail.google.com/a/bexleyseabury.edu <-
#  http://www.bexleyseabury.edu/seabury-in-chicago
#
#  http://bit.ly/1MczHwe <-
#  http://ortchicago.blogspot.com
#
#  http://admissions.iit.edu/undergraduate/visit <-
#  http://www.illinoistechathletics.com
#
#  http://blogs.kentlaw.iit.edu/islat <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://chicagotonight.disqus.com/?url=http%3A%2F%2Fchicagotonight.wttw.com%2F2016%2F02%2F24%2Fapple-vs-fbi-should-privacy-rights-outrank-federal-investigation <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://www.kentlaw.edu/record <-
#  http://web.iit.edu/directory
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142865008796%2Fperfect-capture-from-the-color-run-yesterday&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://calendar.kentlaw.iit.edu <-
#  http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://www.huffingtonpost.com/dr-michael-j-breus/the-freshman-8-and-your-g_b_703155.html <-
#  http://academicresourcecenter.blogspot.com
#
#  http://www.linkedin.com/groupInvitation?gid=71469&sharedKey=2839B80CA393 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.iit.edu <-
#  http://www.youtube.com/user/IITToday
# http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
#
#  http://bit.ly/1iOdCLQ <-
#  http://ortchicago.blogspot.com
#
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4528&information_id=7192&type=&rss=rss <-
#  http://www.kentlaw.edu
#
#  http://www.istockphoto.com/googleimages.php?id=5848437&platform=blogger&langregion=en <-
#  http://ortchicago.blogspot.com
#
#  http://www.thecollegejuice.com <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://www.linkedin.com/groups?gid=4818331&mostPopular=&trk=tyah <-
#  http://resu.edu/academics
#
#  http://www.huffingtonpost.com/2016/04/15/minimum-wage-protests_n_9699048.html?utm_hp_ref=chicago&ir=Chicago <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4153&information_id=6391&type=&rss=rss <-
#  http://www.kentlaw.edu
#
#  http://studentorgs.kentlaw.iit.edu/sba <-
#  http://www.kentlaw.edu/students/organizations.html
#
#  http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education <-
#  http://www.illinoistechathletics.com
#
#  http://forms.bncollegemail.com/email/form2.htm <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://blogs.kentlaw.iit.edu/faculty/2016/04/08/gerber-antitrust-article-award <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student <-
#  http://www.illinoistechathletics.com
#
#  http://blogs.kentlaw.iit.edu/facultynews/research-in-progress-january-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://wildwestonlineproductions.com <-
#  http://ortchicagotech.edu
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142410510351%2Fiit-bot-outstanding-undergraduate-teaching-award&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com
#
#  http://www.huffingtonpost.com/2016/04/13/dennis-hastert-sentencing-lies_n_9697304.html?utm_hp_ref=chicago&ir=Chicago <-
#  http://chicagotonight.wttw.com/2016/02/24/apple-vs-fbi-should-privacy-rights-outrank-federal-investigation
#
#  http://www.youtube.com/user/UICengineering <-
#  http://www.engineering.uic.edu
# http://engineering.uic.edu/COE/UndergraduatePrograms
#
#  http://www.kentlaw.iit.edu/x1235.xml <-
#  http://www.kentlaw.edu/students/organizations.html
#
#  http://ortchicagotech.edu <-
#  http://www.pinterest.com/ortchicago
#
#  http://nahmodlaw.com/2016/02/11/mullinex-v-luna-a-supreme-court-qualified-immunity-excessive-forcehigh-speed-police-chase-decision <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://resu.edu/academics <-
#  https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
#  http://blogs.kentlaw.iit.edu/faculty <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.bncollegejobs.com <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://www.aurp.net <-
#  http://www.universitytechnologypark.com
#
#  http://nahmodlaw.com/2016/01/04/my-class-on-race-dred-scott-and-korematsu-audio <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://www.elsblog.org <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://blogs.kentlaw.edu <-
#  http://web.iit.edu/directory
#
#  http://www.youtube.com/ChicagoKentLaw <-
#  http://blogs.kentlaw.edu
# http://www.kentlaw.edu
# http://www.kentlaw.edu/students/organizations.html
# http://blogs.kentlaw.edu/faculty
#
#  http://www.ncaa.com <-
#  http://www.illinoistechathletics.com
#
#  http://thecollegejuice.com <-
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
#  http://bookstore.mbsdirect.net/resu.htm <-
#  http://resu.edu/academics
#
#  http://blogs.kentlaw.iit.edu/iscotus/weekly-roundup-march-18-2016 <-
#  http://blogs.kentlaw.edu
# http://blogs.kentlaw.edu/faculty
#
#  http://instagram.com/youvisit <-
#  http://www.youvisit.com
#
#  http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142643364801%2Fcongratulation-greeks-to-a-successful-greek-week&t=My%20Illinois%20Tech <-
#  http://myillinoistech.tumblr.com

# %%
print('iit')
print('\n'.join(inlinks['http://web.iit.edu']))
print('uic')
print('\n'.join(inlinks['http://www.engineering.uic.edu']))
# Out:
# iit
# http://www.illinoistechathletics.com
# uic

# %%
# Initialize hubs and authorities scores and print.
hubs = dict([(u, 1.0) for u in urls])
authorities = dict([(u, 1.0) for u in urls])
def print_top(hubs, authorities):
    print('Top hubs\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:5]))
    print('Top authorities\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(authorities.items(), key=lambda x: x[1], reverse=True)[:5]))
    print()

print_top(hubs, authorities)
# Out:
# Top hubs
#  http://blogs.kentlaw.iit.edu/facultynews/feed 1.000000
# http://www.bexleyseabury.edu/seabury-in-chicago 1.000000
# http://www.flickr.com/photos/iitugadmission/sets 1.000000
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142045013856%2Fyou-can-really-tell-when-the-architects-come-to&t=My%20Illinois%20Tech 1.000000
# http://www.huffingtonpost.com/2016/04/13/dennis-hastert-sentencing-lies_n_9697304.html?utm_hp_ref=chicago&ir=Chicago 1.000000
# Top authorities
#  http://blogs.kentlaw.iit.edu/facultynews/feed 1.000000
# http://www.bexleyseabury.edu/seabury-in-chicago 1.000000
# http://www.flickr.com/photos/iitugadmission/sets 1.000000
# http://facebook.com/sharer.php?u=http%3A%2F%2Fmyillinoistech.tumblr.com%2Fpost%2F142045013856%2Fyou-can-really-tell-when-the-architects-come-to&t=My%20Illinois%20Tech 1.000000
# http://www.huffingtonpost.com/2016/04/13/dennis-hastert-sentencing-lies_n_9697304.html?utm_hp_ref=chicago&ir=Chicago 1.000000

# %%
# Update hub and authority scores.
import math

def update(hubs, authorities, inlinks, outlinks):
    for u in authorities:
        authorities[u] += sum([hubs[inlink] for inlink in inlinks[u]])
    normalize(authorities)
    for u in hubs:
        hubs[u] += sum([authorities[outlink] for outlink in outlinks[u]])
    normalize(hubs)

def normalize(d):
    norm = math.sqrt(sum([v * v for v in d.values()]))
    for k in d:
        d[k] /= norm

# %%
update(hubs, authorities, inlinks, outlinks)
print_top(hubs, authorities)
# Out:
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.261201
# http://blogs.kentlaw.edu 0.261201
# http://www.kentlaw.edu 0.153157
# http://www.kentlaw.edu/students/organizations.html 0.141476
# https://admissions.iit.edu/undergraduate 0.141476
# Top authorities
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 0.179961
# http://www.universitytechnologypark.com 0.179961
# http://www.illinoistechathletics.com 0.179961
# http://www.iitri.org 0.179961
# http://www.kentlaw.edu 0.179961

# %%
for i in range(10):
    update(hubs, authorities, inlinks, outlinks)
    print_top(hubs, authorities)
# Out:
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.610643
# http://blogs.kentlaw.edu 0.610643
# http://www.kentlaw.edu 0.209587
# http://www.kentlaw.edu/students/organizations.html 0.190651
# https://admissions.iit.edu/undergraduate 0.174405
# Top authorities
#  http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 0.179312
# http://www.universitytechnologypark.com 0.179312
# http://www.illinoistechathletics.com 0.179312
# http://www.iitri.org 0.179312
# http://www.kentlaw.edu 0.179312
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.669915
# http://blogs.kentlaw.edu 0.669915
# http://www.kentlaw.edu 0.160470
# http://www.kentlaw.edu/students/organizations.html 0.148194
# https://admissions.iit.edu/undergraduate 0.104936
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.183271
# http://blogs.kentlaw.iit.edu 0.183271
# http://twitter.com/ChicagoKentLaw 0.183271
# http://www.youtube.com/ChicagoKentLaw 0.183271
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.135899
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.689193
# http://blogs.kentlaw.edu 0.689193
# http://www.kentlaw.edu 0.131948
# http://www.kentlaw.edu/students/organizations.html 0.123499
# https://admissions.iit.edu/undergraduate 0.059768
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.178375
# http://blogs.kentlaw.iit.edu 0.178375
# http://twitter.com/ChicagoKentLaw 0.178375
# http://www.youtube.com/ChicagoKentLaw 0.178375
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.143704
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.695851
# http://blogs.kentlaw.edu 0.695851
# http://www.kentlaw.edu 0.117528
# http://www.kentlaw.edu/students/organizations.html 0.110988
# https://admissions.iit.edu/undergraduate 0.033566
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.174412
# http://blogs.kentlaw.iit.edu 0.174412
# http://twitter.com/ChicagoKentLaw 0.174412
# http://www.youtube.com/ChicagoKentLaw 0.174412
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.146490
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.698243
# http://blogs.kentlaw.edu 0.698243
# http://www.kentlaw.edu 0.110490
# http://www.kentlaw.edu/students/organizations.html 0.104874
# https://admissions.iit.edu/undergraduate 0.018771
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.172119
# http://blogs.kentlaw.iit.edu 0.172119
# http://twitter.com/ChicagoKentLaw 0.172119
# http://www.youtube.com/ChicagoKentLaw 0.172119
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.147525
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.699144
# http://blogs.kentlaw.edu 0.699144
# http://www.kentlaw.edu 0.107101
# http://www.kentlaw.edu/students/organizations.html 0.101926
# https://admissions.iit.edu/undergraduate 0.010484
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.170916
# http://blogs.kentlaw.iit.edu 0.170916
# http://twitter.com/ChicagoKentLaw 0.170916
# http://www.youtube.com/ChicagoKentLaw 0.170916
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.147926
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.699500
# http://blogs.kentlaw.edu 0.699500
# http://www.kentlaw.edu 0.105479
# http://www.kentlaw.edu/students/organizations.html 0.100514
# https://admissions.iit.edu/undergraduate 0.005853
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.170311
# http://blogs.kentlaw.iit.edu 0.170311
# http://twitter.com/ChicagoKentLaw 0.170311
# http://www.youtube.com/ChicagoKentLaw 0.170311
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.148090
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.699647
# http://blogs.kentlaw.edu 0.699647
# http://www.kentlaw.edu 0.104704
# http://www.kentlaw.edu/students/organizations.html 0.099840
# https://admissions.iit.edu/undergraduate 0.003267
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.170014
# http://blogs.kentlaw.iit.edu 0.170014
# http://twitter.com/ChicagoKentLaw 0.170014
# http://www.youtube.com/ChicagoKentLaw 0.170014
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.148159
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.699710
# http://blogs.kentlaw.edu 0.699710
# http://www.kentlaw.edu 0.104335
# http://www.kentlaw.edu/students/organizations.html 0.099519
# http://www.youtube.com/user/IITToday 0.002325
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.169870
# http://blogs.kentlaw.iit.edu 0.169870
# http://twitter.com/ChicagoKentLaw 0.169870
# http://www.youtube.com/ChicagoKentLaw 0.169870
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.148189
#
# Top hubs
#  http://blogs.kentlaw.edu/faculty 0.699738
# http://blogs.kentlaw.edu 0.699738
# http://www.kentlaw.edu 0.104159
# http://www.kentlaw.edu/students/organizations.html 0.099366
# http://www.youtube.com/user/IITToday 0.002314
# Top authorities
#  http://www.facebook.com/ChicagoKentLaw 0.169801
# http://blogs.kentlaw.iit.edu 0.169801
# http://twitter.com/ChicagoKentLaw 0.169801
# http://www.youtube.com/ChicagoKentLaw 0.169801
# http://blogs.kentlaw.iit.edu/facultynews/feed 0.148203

# %% [markdown]
# ## Expanding the set of urls
#
# - How does restricting to only 20 links from each url limit these results?
# - For a given query, begin with the *root* set of the top $k$ matching documents.
# - Expand the set to include all forward and backward links from the root.
#
#
# When would this help?
