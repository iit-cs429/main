# %% [markdown]
# # CS 429: Information Retrieval
# <br>
#
# ## Lecture 26: HITS
#
# <br>
#
# ### Dr. Aron Culotta
# ### Illinois Institute of Technology
# ### Spring 2015

# %% [markdown]
# The **Hubs and Authorities** algorithm is a simple procedure to assign each page two scores:
#
# - **hub score:** how likely is this page to be a directory?
# - **authority score:** how likely is this page to be a trustworthy resource on a topic?

# %% [markdown]
# Let $F_u$ be *forward* links (going out from $u$).
#
# Let $B_u$ be *back* links (going in to $u$).
#
# $$ \begin{align}
# h(u) = \sum_{v \in F_u} a(v)\\
# a(u) = \sum_{v \in B_u} h(v)\\
# \end{align}$$
#
# In words:
#
# - The hub score for $u$ is the sum of the authority scores for all pages linked from $u$.
# - The authority score for $u$ is the sum of the hub scores for all pages linking to $u$.

# %% [markdown]
# As for PageRank, we can compute these iteratively until convergence:
#
# 1. Initialize all hub/authority scores to 1.0
# 2. Loop until convergence
#   1. update authority scores
#   2. update hub scores

# %% [markdown]
# Let's try this out on some real data:

# %%
# See http://stackoverflow.com/questions/1657570/google-search-from-a-python-app
import json
import urllib

def clean_url(url):
    if url[-1] == '/':
        return url[:-1]
    else:
        return url
    
def search_google(query_str):
    query = urllib.urlencode({'q': query_str})
    url = 'http://ajax.googleapis.com/ajax/services/search/web?v=1.0&%s&rsz=4' % query
    search_response = urllib.urlopen(url)
    search_results = search_response.read()
    results = json.loads(search_results)
    data = results['responseData']
    hits = data['results']
    return set([clean_url(h['url']) for h in hits])

# %%
# Get some search results.
urls = search_google('chicago technical universities')
print 'top', len(urls), 'results:\n', '\n'.join(urls)
# Out:
# top 4 results:
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# http://www.engineering.uic.edu
# http://web.iit.edu
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691

# %%
from urlparse import urlparse
def get_domain(s):
    return '_'.join(urlparse(s).netloc.split('.')[-2:])
print get_domain('http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691')
# Out:
# rankingsandreviews_com

# %%
# Download links for each url. Store inlinks/outlinks for each page in original set.
from collections import defaultdict
import requests
import time
from urlparse import urlparse
from BeautifulSoup import BeautifulSoup

    
def crawl(toprocess, depth=2):
    """ Crawl pages from seed set."""
    processed = set()
    inlinks = defaultdict(lambda: set())   # url -> set of inlinks
    outlinks = defaultdict(lambda: set())  # url -> set of outlinks 

    for i in range(depth):  # depth to crawl
        toprocess -= processed
        new_urls = set()
        for url in toprocess:
            print 'url=', url
            domain = get_domain(url)
            soup = BeautifulSoup(requests.get(url).text)
            processed.add(url)
            links = set([clean_url(a['href']) for a in soup.findAll('a') if a.get('href') and
                                                                            a['href'][:5] == 'http:' and
                                                                            get_domain(a['href']) != domain])
            print 'found %d links' % len(links)
            outlinks[url] = links
            for link in links:
                inlinks[link].add(url)
            # Add links to be processed
            links = [l for l in links if l not in processed and l not in toprocess][:20]
            new_urls |= set(links)
        toprocess = new_urls
    return inlinks, outlinks
    
inlinks, outlinks = crawl(urls)
# Out:
# url= http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# found 2 links
# url= http://www.engineering.uic.edu
# found 3 links
# url= http://web.iit.edu
# found 6 links
# url= http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# found 37 links
# url= http://travel.usnews.com/cruises
# found 3 links
# url= http://bestlawfirms.usnews.com/rankings.aspx
# found 6 links
# url= http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# found 8 links
# url= http://twitter.com/UICEngineering
# found 21 links
# url= http://money.usnews.com/funds/mutual-funds
# found 5 links
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# url= http://www.youtube.com/user/UICengineering
# found 1 links
# url= http://www.universitytechnologypark.com
# found 4 links
# url= http://health.usnews.com
# found 4 links
# url= http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# found 11 links
# url= http://www.iitri.org
# found 1 links
# url= http://mediakit.usnews.com/index.php
# found 1 links
# url= http://nces.ed.gov/collegenavigator/?s=IL
# found 3 links
# url= http://beonair.com/about
# found 2 links
# url= http://twitter.com/#!/usnewseducation
# found 0 links
# url= http://travel.usnews.com/Rankings
# found 8 links
# url= http://travel.usnews.com/Hotels
# found 6 links
# url= http://travel.usnews.com
# found 3 links
# url= http://www.iitmicrogrid.net
# found 0 links
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# url= http://www.flickr.com/photos/uic_engineering/sets
# found 7 links
# url= http://money.usnews.com/money/careers
# found 5 links
# url= http://www.usnews.com
# found 3 links
# url= http://www.kentlaw.edu
# found 20 links
# url= http://money.usnews.com/529s
# found 3 links
# url= http://health.usnews.com/doctors
# found 3 links
# url= http://health.usnews.com/best-nursing-homes
# found 3 links
# url= http://www.illinoistechathletics.com
# found 17 links
# url= http://health.usnews.com/health-news/best-hospitals
# found 6 links
# url= http://health.usnews.com/health-products
# found 4 links
# url= http://www.usnews.com/education/best-colleges/paying-for-college
# found 9 links
# url= http://www.usnews.com/rss/education
# found 0 links
# url= http://health.usnews.com/health-insurance
# found 4 links

# %%
urls = set(inlinks.keys() + outlinks.keys())
print '%d total urls' % len(urls)
# Out:
# 165 total urls

# %%
# Print outlinks.
for url in outlinks:
    if len(outlinks[url]) > 0:
        print '\n', url, '->\n', '\n'.join(outlinks[url])
# Out:
# http://travel.usnews.com/cruises ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com/education/best-colleges/paying-for-college ->
# http://www.usnewsuniversitydirectory.com/masters-mba.aspx
# http://www.usnewsuniversitydirectory.com/bachelors.aspx
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.usnewsuniversitydirectory.com/Colleges-Universities/financialaid/?mcid=53158
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://www.usnewsuniversitydirectory.com/certificates.aspx
# http://www.usnewsuniversitydirectory.com
# http://www.usnewsuniversitydirectory.com/associates.aspx
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://money.usnews.com/funds/mutual-funds ->
# http://www.interactivedata.com
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.morningstar.com/IntroPage.aspx
#
# http://twitter.com/UICEngineering ->
# http://t.co/IHS6wQJn53
# http://t.co/ot3qjGFxW5
# http://t.co/fTZJPTLz7Z
# http://t.co/XeBvC03gDZ
# http://t.co/oI7oAySmvZ
# http://t.co/BTVdVcTWbN
# http://t.co/LfqtxCqiW1
# http://t.co/fkADHybJVX
# http://t.co/QO23byb5jK
# http://t.co/Hw7YrdV7fy
# http://t.co/TNJqfncVl6
# http://t.co/d76QlyoXXm
# http://t.co/rpbLi1a27M
# http://t.co/0aXUtqPbBW
# http://t.co/GoeCMjyy9o
# http://t.co/krCmOjpXky
# http://t.co/0nkACtRozg
# http://t.co/vInl2DVjt9
# http://t.co/QC6GAkeEyI
# http://t.co/yFFo4Dm0Oi
# http://t.co/MwQmPtF0wg
#
# http://beonair.com/about ->
# http://www.facebook.com/ohiocenterforbroadcasting
# http://www.facebook.com/BeOnAirIllinois
#
# http://health.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 ->
# http://www.facebook.com/usnewsbestcolleges
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://trk.usnud.net/?a=14&oc=296&c=4240&m=17&s1=54096
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691/jobs
# http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-graduate-schools/illinois-institute-of-technology-145725
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://colleges.usnews.rankingsandreviews.com/best-colleges/illinois-institute-of-technology-145725/overall-rankings
# http://twitter.com/#!/usnewseducation
#
# http://www.iitri.org ->
# http://www.iubenda.com/privacy-policy/264605
#
# http://health.usnews.com/best-nursing-homes ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://nces.ed.gov/collegenavigator/?s=IL ->
# http://www.childstats.gov
# http://www.bls.gov/oco
# http://fedstats.sites.usa.gov
#
# http://travel.usnews.com/Hotels ->
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=15939357&agid=5099&c=5115&l=3&e=4&f=147237&av=1343&g=76460f2db7&j=6&sig=be47225021507dfe4ad319ca39b9087c
# http://usnews.rankingsandreviews.com/cars-trucks
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=17565254&agid=5099&c=5115&l=2&e=4&f=147237&av=1343&g=76460f2db7&j=6&sig=206c970110d5e99288868ec159991d2c
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=17574435&agid=5077&c=5093&l=1&e=4&f=147237&av=288&g=22232db0fd&j=6&sig=a97402a0da1fb535d6744321099bcb13
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://travel.usnews.com/Rankings ->
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=9199858&agid=4709&c=4725&l=3&e=3&f=60745&av=9&g=7be49dee27&j=6&w=89599&sig=892017ba5e11f9daffd5b966296e871a
# http://usnews.rankingsandreviews.com/cars-trucks
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=17349397&agid=4999&c=5015&l=2&e=1&f=60745&av=241&g=a27a5b01a3&j=6&sig=9558bd50f311814acec70d4028acde47
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=16505196&agid=4709&c=4725&l=5&e=3&f=60745&av=9&g=cb24743bad&j=6&w=321151&sig=5524306de75d904afc22f5ce9db5e222
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=16595531&agid=4999&c=5015&l=4&e=1&f=60745&av=241&g=c7698d53ec&j=6&sig=e30f8d86703fe809d59270dcb25de423
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=7541543&agid=4709&c=4725&l=1&e=3&f=60745&av=9&g=a5c1ffa2bf&j=6&w=89599&sig=2b28f80c2cf5d9fbb3a1516d60163624
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://travel.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.flickr.com/photos/uic_engineering/sets ->
# http://blog.flickr.net
# http://sports.yahoo.com
# http://everything.yahoo.com
# http://flickr.tumblr.com
# http://finance.yahoo.com
# http://shopping.yahoo.com
# http://news.yahoo.com
#
# http://money.usnews.com/money/careers ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://www.indeed.com
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/rankings/used
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.kentlaw.edu ->
# http://twitter.com/ChicagoKentLaw
# http://www.dtc.bkstore.com
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4269&information_id=6623&type=&rss=rss
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4169&information_id=6339&type=&rss=rss
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A
# http://www.iit.edu/cdr
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=798&information_id=2550&type=&rss=rss
# http://instagram.com/chicagokentlaw
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4118&information_id=6227&type=&rss=rss
# http://www.facebook.com/ChicagoKentLaw
# http://www.iit.edu/about/department_sites.shtml
# http://www.youtube.com/ChicagoKentLaw
# http://blogs.kentlaw.iit.edu
# http://www.iit.edu
# http://calendar.kentlaw.iit.edu
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=800&information_id=2554&type=&rss=rss
# http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014
# http://www.iit.edu/directory/shuttlebus.html
# http://www.oyez.org
#
# http://money.usnews.com/529s ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://health.usnews.com/doctors ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://health.usnews.com/health-news/best-hospitals ->
# http://www.aha.org
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://twitter.com/#!/USNewsHealth
#
# http://health.usnews.com/health-products ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://mediakit.usnews.com/index.php ->
# http://usnews.rankingsandreviews.com/cars-trucks
#
# http://health.usnews.com/health-insurance ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://www.ehealthinsurance.com/?allid=USN27889
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 ->
# http://thecollegejuice.com
# http://www.facultyenlight.com/?storeNbr=296
# http://www.bncollegejobs.com
# http://www.facebook.com/IITbookstore
# http://www.thecollegejuice.com
# http://forms.bncollegemail.com/email/form2.htm
# http://www.iit.edu
# http://www.barnesandnoble.com/include/copyright.asp
#
# http://www.engineering.uic.edu ->
# http://www.flickr.com/photos/uic_engineering/sets
# http://twitter.com/UICEngineering
# http://www.youtube.com/user/UICengineering
#
# http://www.youtube.com/user/UICengineering ->
# http://www.engr.uic.edu
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 ->
# http://travel.usnews.com/cruises
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/funds/mutual-funds
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://twitter.com/#!/usnewseducation
# http://travel.usnews.com/Rankings
# http://travel.usnews.com
# http://money.usnews.com/money/careers
# http://money.usnews.com/529s
# http://health.usnews.com/doctors
# http://www.usnews.com/rss/education
# http://health.usnews.com/health-news/best-hospitals
# http://health.usnews.com/health-products
# http://health.usnews.com/health-insurance
# http://bestlawfirms.usnews.com/rankings.aspx
# http://mediakit.usnews.com/index.php
# http://www.usnews.com
# http://money.usnews.com/financial-advisors
# http://health.usnews.com/best-diet
# http://www.usnews.com/education/best-colleges/applying
# http://money.usnews.com/funds/etfs
# http://www.facebook.com/usnewsbestcolleges
# http://money.usnews.com
# http://travel.usnews.com/Rankings/Travel-Rewards/hotel-rewards
# http://travel.usnews.com/Rankings/Travel-Rewards/airline-rewards
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://bestlawfirms.usnews.com
# http://www.usnews.com/products/features/home
# http://health.usnews.com/medicare
# http://iit.edu/undergrad_admission
# http://video.usnews.com
# http://money.usnews.com/money/retirement
# http://www.usnews.com/usnews/store/college_compass.htm?src=gauge&ref=/colleges/myfit-dashboard
# http://aftercollege.com
#
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago ->
# http://nces.ed.gov/collegenavigator/?s=IL
# http://beonair.com/about
#
# http://bestlawfirms.usnews.com/rankings.aspx ->
# http://plus.google.com/+usnewsworldreport
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://www.facebook.com/usnewsandworldreport
# http://twitter.com/usnews
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://web.iit.edu ->
# http://www.iitmicrogrid.net
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.kentlaw.edu
# http://www.universitytechnologypark.com
# http://www.illinoistechathletics.com
# http://www.iitri.org
#
# http://www.universitytechnologypark.com ->
# http://www.nbia.org
# http://www.aurp.net/aurp-awards-of-excellence
# http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775
# http://www.aurp.net
#
# http://www.illinoistechathletics.com ->
# http://web.iit.edu/about/campus-locations
# http://www.theuscaa.com/landing/index
# http://www.adidas.com/us
# http://web.iit.edu
# http://admissions.iit.edu/undergraduate
# http://www.mlc-mwlc.org/landing/index
# http://admissions.iit.edu/undergraduate/apply
# http://www.ncaa.com
# http://admissions.iit.edu/undergraduate/programs
# http://www.d3sports.com/landing/index
# http://wcsphoto.zenfolio.com/f417637883
# http://www.collegecostcalculator.org/IIT
# http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education
# http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student
# http://www.prestosports.com
# http://admissions.iit.edu/undergraduate/visit
# http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student

# %%
for url in outlinks:
    print url, len(outlinks[url])
# Out:
# http://travel.usnews.com/cruises 3
# http://www.usnews.com/education/best-colleges/paying-for-college 9
# http://money.usnews.com/funds/mutual-funds 5
# http://twitter.com/UICEngineering 21
# http://beonair.com/about 2
# http://health.usnews.com 4
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 11
# http://www.iitri.org 1
# http://health.usnews.com/best-nursing-homes 3
# http://nces.ed.gov/collegenavigator/?s=IL 3
# http://travel.usnews.com/Hotels 6
# http://twitter.com/#!/usnewseducation 0
# http://travel.usnews.com/Rankings 8
# http://travel.usnews.com 3
# http://www.iitmicrogrid.net 0
# http://www.flickr.com/photos/uic_engineering/sets 7
# http://money.usnews.com/money/careers 5
# http://www.usnews.com 3
# http://www.kentlaw.edu 20
# http://money.usnews.com/529s 3
# http://health.usnews.com/doctors 3
# http://www.usnews.com/rss/education 0
# http://health.usnews.com/health-news/best-hospitals 6
# http://health.usnews.com/health-products 4
# http://mediakit.usnews.com/index.php 1
# http://health.usnews.com/health-insurance 4
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 8
# http://www.engineering.uic.edu 3
# http://www.youtube.com/user/UICengineering 1
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 37
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago 2
# http://bestlawfirms.usnews.com/rankings.aspx 6
# http://web.iit.edu 6
# http://www.universitytechnologypark.com 4
# http://www.illinoistechathletics.com 17

# %%
# Print inlinks
for url in inlinks:
    if len(inlinks[url]) > 0:
        print '\n', url, '<-\n', '\n'.join(inlinks[url])
# Out:
# http://plus.google.com/+usnewsworldreport <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://t.co/XeBvC03gDZ <-
# http://twitter.com/UICEngineering
#
# http://www.theuscaa.com/landing/index <-
# http://www.illinoistechathletics.com
#
# http://www.iubenda.com/privacy-policy/264605 <-
# http://www.iitri.org
#
# http://forms.bncollegemail.com/email/form2.htm <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.prestosports.com <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775 <-
# http://www.universitytechnologypark.com
#
# http://beonair.com/about <-
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
# http://health.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://twitter.com/usnews <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://t.co/krCmOjpXky <-
# http://twitter.com/UICEngineering
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/illinois-institute-of-technology-145725/overall-rankings <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014 <-
# http://www.kentlaw.edu
#
# http://twitter.com/#!/usnewseducation <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnews.com/education/best-colleges/applying <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=17565254&agid=5099&c=5115&l=2&e=4&f=147237&av=1343&g=76460f2db7&j=6&sig=206c970110d5e99288868ec159991d2c <-
# http://travel.usnews.com/Hotels
#
# http://t.co/fkADHybJVX <-
# http://twitter.com/UICEngineering
#
# http://t.co/Hw7YrdV7fy <-
# http://twitter.com/UICEngineering
#
# http://health.usnews.com/doctors <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://health.usnews.com/health-products <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://sports.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://t.co/BTVdVcTWbN <-
# http://twitter.com/UICEngineering
#
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/money/retirement <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnewsuniversitydirectory.com/Colleges-Universities/financialaid/?mcid=53158 <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4269&information_id=6623&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://instagram.com/chicagokentlaw <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/financial-advisors <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://wcsphoto.zenfolio.com/f417637883 <-
# http://www.illinoistechathletics.com
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=17574435&agid=5077&c=5093&l=1&e=4&f=147237&av=288&g=22232db0fd&j=6&sig=a97402a0da1fb535d6744321099bcb13 <-
# http://travel.usnews.com/Hotels
#
# http://www.barnesandnoble.com/include/copyright.asp <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://finance.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://news.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://travel.usnews.com/Rankings/Travel-Rewards/hotel-rewards <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://travel.usnews.com/Rankings/Travel-Rewards/airline-rewards <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.linkedin.com/company/u.s.-news-&-world-report <-
# http://money.usnews.com/money/careers
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/health-news/best-hospitals
# http://health.usnews.com/health-products
#
# http://health.usnews.com/medicare <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4118&information_id=6227&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://www.nbia.org <-
# http://www.universitytechnologypark.com
#
# http://www.illinoistechathletics.com <-
# http://web.iit.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=7541543&agid=4709&c=4725&l=1&e=3&f=60745&av=9&g=a5c1ffa2bf&j=6&w=89599&sig=2b28f80c2cf5d9fbb3a1516d60163624 <-
# http://travel.usnews.com/Rankings
#
# http://www.ncaa.com <-
# http://www.illinoistechathletics.com
#
# http://www.oyez.org <-
# http://www.kentlaw.edu
#
# http://www.d3sports.com/landing/index <-
# http://www.illinoistechathletics.com
#
# http://calendar.kentlaw.iit.edu <-
# http://www.kentlaw.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=hE4KYOhnEeSPyjZg6C6xQA&cid=2079840&pid=70&d=33388&p=28&y=3&x=3&m=0&t=0&s=1024&aid=15939357&agid=5099&c=5115&l=3&e=4&f=147237&av=1343&g=76460f2db7&j=6&sig=be47225021507dfe4ad319ca39b9087c <-
# http://travel.usnews.com/Hotels
#
# http://www.usnews.com/education/best-colleges/paying-for-college <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://twitter.com/UICEngineering <-
# http://www.engineering.uic.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=16595531&agid=4999&c=5015&l=4&e=1&f=60745&av=241&g=c7698d53ec&j=6&sig=e30f8d86703fe809d59270dcb25de423 <-
# http://travel.usnews.com/Rankings
#
# http://www.iitri.org <-
# http://web.iit.edu
#
# http://nces.ed.gov/collegenavigator/?s=IL <-
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
# http://travel.usnews.com/Hotels <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=800&information_id=2554&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://travel.usnews.com/Rankings <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.facultyenlight.com/?storeNbr=296 <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.usnewsuniversitydirectory.com/masters-mba.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://www.usnewsuniversitydirectory.com/certificates.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://www.iit.edu/cdr <-
# http://www.kentlaw.edu
#
# http://www.kentlaw.edu <-
# http://web.iit.edu
#
# http://usnews.rankingsandreviews.com/cars-trucks/rankings <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://www.usnews.com
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://fedstats.sites.usa.gov <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://mediakit.usnews.com/index.php <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.iit.edu/directory/shuttlebus.html <-
# http://www.kentlaw.edu
#
# http://health.usnews.com/health-insurance <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://thecollegejuice.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://flickr.tumblr.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://www.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.thecollegejuice.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.youtube.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education <-
# http://www.illinoistechathletics.com
#
# http://t.co/0aXUtqPbBW <-
# http://twitter.com/UICEngineering
#
# http://twitter.com/#!/USNewsHealth <-
# http://health.usnews.com/health-news/best-hospitals
#
# http://admissions.iit.edu/undergraduate/visit <-
# http://www.illinoistechathletics.com
#
# http://money.usnews.com/funds/etfs <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.facebook.com/usnewsbestcolleges <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://money.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.ehealthinsurance.com/?allid=USN27889 <-
# http://health.usnews.com/health-insurance
#
# http://iit.edu/undergrad_admission <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=17349397&agid=4999&c=5015&l=2&e=1&f=60745&av=241&g=a27a5b01a3&j=6&sig=9558bd50f311814acec70d4028acde47 <-
# http://travel.usnews.com/Rankings
#
# http://t.co/oI7oAySmvZ <-
# http://twitter.com/UICEngineering
#
# http://t.co/ot3qjGFxW5 <-
# http://twitter.com/UICEngineering
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4169&information_id=6339&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://www.usnewsuniversitydirectory.com <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://www.usnews.com/usnews/store/college_compass.htm?src=gauge&ref=/colleges/myfit-dashboard <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.aurp.net <-
# http://www.universitytechnologypark.com
#
# http://blog.flickr.net <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://admissions.iit.edu/undergraduate <-
# http://www.illinoistechathletics.com
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=798&information_id=2550&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://everything.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://t.co/d76QlyoXXm <-
# http://twitter.com/UICEngineering
#
# http://t.co/GoeCMjyy9o <-
# http://twitter.com/UICEngineering
#
# http://www.iit.edu/about/department_sites.shtml <-
# http://www.kentlaw.edu
#
# http://www.iitmicrogrid.net <-
# http://web.iit.edu
#
# http://www.flickr.com/photos/uic_engineering/sets <-
# http://www.engineering.uic.edu
#
# http://t.co/QO23byb5jK <-
# http://twitter.com/UICEngineering
#
# http://money.usnews.com/529s <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnewsuniversitydirectory.com/bachelors.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://health.usnews.com/health-news/best-hospitals <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.bncollegejobs.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.usnewsuniversitydirectory.com/associates.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://t.co/yFFo4Dm0Oi <-
# http://twitter.com/UICEngineering
#
# http://www.interactivedata.com <-
# http://money.usnews.com/funds/mutual-funds
#
# http://twitter.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://www.childstats.gov <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://www.iit.edu <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.kentlaw.edu
#
# http://www.morningstar.com/IntroPage.aspx <-
# http://money.usnews.com/funds/mutual-funds
#
# http://www.youtube.com/user/UICengineering <-
# http://www.engineering.uic.edu
#
# http://t.co/rpbLi1a27M <-
# http://twitter.com/UICEngineering
#
# http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-graduate-schools/illinois-institute-of-technology-145725 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://health.usnews.com/best-diet <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student <-
# http://www.illinoistechathletics.com
#
# http://t.co/vInl2DVjt9 <-
# http://twitter.com/UICEngineering
#
# http://t.co/MwQmPtF0wg <-
# http://twitter.com/UICEngineering
#
# http://t.co/IHS6wQJn53 <-
# http://twitter.com/UICEngineering
#
# http://usnews.rankingsandreviews.com/cars-trucks <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://mediakit.usnews.com/index.php
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://www.usnews.com
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://www.facebook.com/usnewsandworldreport <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://www.usnews.com/products/features/home <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.bls.gov/oco <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://www.facebook.com/IITbookstore <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.facebook.com/BeOnAirIllinois <-
# http://beonair.com/about
#
# http://video.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/LfqtxCqiW1 <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student <-
# http://www.illinoistechathletics.com
#
# http://aftercollege.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://travel.usnews.com/cruises <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://usnews.rankingsandreviews.com/cars-trucks/rankings/used <-
# http://www.usnews.com
#
# http://trk.usnud.net/?a=14&oc=296&c=4240&m=17&s1=54096 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://money.usnews.com/funds/mutual-funds <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/TNJqfncVl6 <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/programs <-
# http://www.illinoistechathletics.com
#
# http://health.usnews.com/best-nursing-homes <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/0nkACtRozg <-
# http://twitter.com/UICEngineering
#
# http://www.adidas.com/us <-
# http://www.illinoistechathletics.com
#
# http://travel.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://blogs.kentlaw.iit.edu <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/money/careers <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnews.com/rss/education <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://web.iit.edu/about/campus-locations <-
# http://www.illinoistechathletics.com
#
# http://www.dtc.bkstore.com <-
# http://www.kentlaw.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=9199858&agid=4709&c=4725&l=3&e=3&f=60745&av=9&g=7be49dee27&j=6&w=89599&sig=892017ba5e11f9daffd5b966296e871a <-
# http://travel.usnews.com/Rankings
#
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 <-
# http://web.iit.edu
#
# http://t.co/QC6GAkeEyI <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/apply <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://www.collegecostcalculator.org/IIT <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/ohiocenterforbroadcasting <-
# http://beonair.com/about
#
# http://bestlawfirms.usnews.com/rankings.aspx <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.aurp.net/aurp-awards-of-excellence <-
# http://www.universitytechnologypark.com
#
# http://www.indeed.com <-
# http://money.usnews.com/money/careers
#
# http://t.co/fTZJPTLz7Z <-
# http://twitter.com/UICEngineering
#
# http://bestlawfirms.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://web.iit.edu <-
# http://www.illinoistechathletics.com
#
# http://www.universitytechnologypark.com <-
# http://web.iit.edu
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691/jobs <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.engr.uic.edu <-
# http://www.youtube.com/user/UICengineering
#
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393 <-
# http://www.kentlaw.edu
#
# http://www.aha.org <-
# http://health.usnews.com/health-news/best-hospitals
#
# http://www.mlc-mwlc.org/landing/index <-
# http://www.illinoistechathletics.com
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=fWS-IOhmEeSPyjZg6C6xQA&cid=2710537&pid=70&d=191&p=43699&y=3&x=3&m=0&t=0&s=1009&aid=16505196&agid=4709&c=4725&l=5&e=3&f=60745&av=9&g=cb24743bad&j=6&w=321151&sig=5524306de75d904afc22f5ce9db5e222 <-
# http://travel.usnews.com/Rankings
#
# http://shopping.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets

# %%
print 'iit'
print '\n'.join(inlinks['http://web.iit.edu'])
print 'uic'
print '\n'.join(inlinks['http://www.engineering.uic.edu'])
# Out:
# iit
# http://www.illinoistechathletics.com
# uic

# %%
# Initialize hubs and authorities scores and print.
hubs = dict([(u, 1.0) for u in urls])
authorities = dict([(u, 1.0) for u in urls])
def print_top(hubs, authorities):
    print 'Top hubs\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:5])
    print 'Top authorities\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(authorities.items(), key=lambda x: x[1], reverse=True)[:5])
    print

print_top(hubs, authorities)
# Out:
# Top hubs
# http://plus.google.com/+usnewsworldreport 1.000000
# http://t.co/XeBvC03gDZ 1.000000
# http://www.theuscaa.com/landing/index 1.000000
# http://www.iubenda.com/privacy-policy/264605 1.000000
# http://forms.bncollegemail.com/email/form2.htm 1.000000
# Top authorities
# http://plus.google.com/+usnewsworldreport 1.000000
# http://t.co/XeBvC03gDZ 1.000000
# http://www.theuscaa.com/landing/index 1.000000
# http://www.iubenda.com/privacy-policy/264605 1.000000
# http://forms.bncollegemail.com/email/form2.htm 1.000000

# %%
# Update hub and authority scores.
import math

def update(hubs, authorities, inlinks, outlinks):
    for u in authorities:
        authorities[u] += sum([hubs[inlink] for inlink in inlinks[u]])
    normalize(authorities)
    for u in hubs:
        hubs[u] += sum([authorities[outlink] for outlink in outlinks[u]])
    normalize(hubs)

def normalize(d):
    norm = math.sqrt(sum([v * v for v in d.values()]))
    for k in d:
        d[k] /= norm

# %%
update(hubs, authorities, inlinks, outlinks)
print_top(hubs, authorities)
# Out:
# Top hubs
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 0.180879
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.174946
# http://www.usnews.com/education/best-colleges/paying-for-college 0.158629
# http://health.usnews.com/health-news/best-hospitals 0.157146
# http://travel.usnews.com/Rankings 0.155662
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.464105
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.439679
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.415252
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.170986
# http://twitter.com/#!/usnewseducation 0.073280

# %%
for i in range(10):
    update(hubs, authorities, inlinks, outlinks)
    print_top(hubs, authorities)
# Out:
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.288601
# http://health.usnews.com/health-news/best-hospitals 0.251467
# http://money.usnews.com/money/careers 0.246434
# http://www.usnews.com/education/best-colleges/paying-for-college 0.244805
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 0.241600
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.534201
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.514471
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.489577
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.198547
# http://twitter.com/#!/usnewseducation 0.074698
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296570
# http://health.usnews.com/health-news/best-hospitals 0.258423
# http://money.usnews.com/money/careers 0.253477
# http://www.usnews.com/education/best-colleges/paying-for-college 0.248751
# http://health.usnews.com 0.248712
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.549737
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.537580
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.515827
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.209004
# http://twitter.com/#!/usnewseducation 0.073946
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.298029
# http://health.usnews.com/health-news/best-hospitals 0.260468
# http://money.usnews.com/money/careers 0.255519
# http://health.usnews.com 0.250755
# http://health.usnews.com/health-products 0.250755
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.555110
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.544440
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.523356
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.208730
# http://twitter.com/#!/usnewseducation 0.070586
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.298071
# http://health.usnews.com/health-news/best-hospitals 0.261350
# http://money.usnews.com/money/careers 0.256382
# http://health.usnews.com 0.251600
# http://health.usnews.com/health-products 0.251600
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.558173
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.547723
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.526694
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.206587
# http://twitter.com/#!/usnewseducation 0.067401
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.297768
# http://health.usnews.com/health-news/best-hospitals 0.261815
# http://money.usnews.com/money/careers 0.256835
# http://www.usnews.com/education/best-colleges/paying-for-college 0.252243
# http://health.usnews.com 0.252040
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.560158
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.549710
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.528627
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.204437
# http://twitter.com/#!/usnewseducation 0.064813
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.297420
# http://health.usnews.com/health-news/best-hospitals 0.262096
# http://money.usnews.com/money/careers 0.257108
# http://www.usnews.com/education/best-colleges/paying-for-college 0.252844
# http://health.usnews.com 0.252306
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.561518
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.551046
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.529903
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.202649
# http://twitter.com/#!/usnewseducation 0.062797
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.297112
# http://health.usnews.com/health-news/best-hospitals 0.262280
# http://money.usnews.com/money/careers 0.257287
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253285
# http://health.usnews.com 0.252480
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.562481
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.551986
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.530796
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.201240
# http://twitter.com/#!/usnewseducation 0.061249
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296858
# http://health.usnews.com/health-news/best-hospitals 0.262405
# http://money.usnews.com/money/careers 0.257408
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253611
# http://health.usnews.com 0.252599
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.563176
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.552663
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.531437
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.200151
# http://twitter.com/#!/usnewseducation 0.060068
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296656
# http://health.usnews.com/health-news/best-hospitals 0.262493
# http://money.usnews.com/money/careers 0.257494
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253852
# http://health.usnews.com 0.252682
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.563684
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.553158
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.531905
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.199316
# http://twitter.com/#!/usnewseducation 0.059169
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296498
# http://health.usnews.com/health-news/best-hospitals 0.262555
# http://money.usnews.com/money/careers 0.257555
# http://www.usnews.com/education/best-colleges/paying-for-college 0.254031
# http://health.usnews.com 0.252741
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.564058
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.553522
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.532250
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.198679
# http://twitter.com/#!/usnewseducation 0.058486

# %% [markdown]
# ## Expanding the set of urls
#
# - How does restricting to only 20 links from each url limit these results?
# - For a given query, begin with the *root* set of the top $k$ matching documents.
# - Expand the set to include all forward and backward links from the root.
#
#
# When would this help?
