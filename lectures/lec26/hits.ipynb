# %% [markdown]
# # CS 429: Information Retrieval
# <br>
#
# ## Lecture 26: HITS
#
# <br>
#
# ### Dr. Aron Culotta
# ### Illinois Institute of Technology
# ### Spring 2015

# %% [markdown]
# The **Hubs and Authorities** algorithm is a simple procedure to assign each page two scores:
#
# - **hub score:** how likely is this page to be a directory?
# - **authority score:** how likely is this page to be a trustworthy resource on a topic?

# %% [markdown]
# Let $F_u$ be *forward* links (going out from $u$).
#
# Let $B_u$ be *back* links (going in to $u$).
#
# $$ \begin{align}
# h(u) = \sum_{v \in F_u} a(v)\\
# a(u) = \sum_{v \in B_u} h(v)\\
# \end{align}$$
#
# In words:
#
# - The hub score for $u$ is the sum of the authority scores for all pages linked from $u$.
# - The authority score for $u$ is the sum of the hub scores for all pages linking to $u$.

# %% [markdown]
# As for PageRank, we can compute these iteratively until convergence:
#
# 1. Initialize all hub/authority scores to 1.0
# 2. Loop until convergence
#   1. update authority scores
#   2. update hub scores

# %% [markdown]
# Let's try this out on some real data:

# %%
# See http://stackoverflow.com/questions/1657570/google-search-from-a-python-app
import json
import urllib

def clean_url(url):
    if url[-1] == '/':
        return url[:-1]
    else:
        return url
    
def search_google(query_str):
    query = urllib.urlencode({'q': query_str})
    url = 'http://ajax.googleapis.com/ajax/services/search/web?v=1.0&%s&rsz=4' % query
    search_response = urllib.urlopen(url)
    search_results = search_response.read()
    results = json.loads(search_results)
    data = results['responseData']
    hits = data['results']
    return set([clean_url(h['url']) for h in hits])

# %%
# Get some search results.
urls = search_google('chicago technical universities')
print 'top', len(urls), 'results:\n', '\n'.join(urls)
# Out:
# top 4 results:
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# http://www.engineering.uic.edu
# http://web.iit.edu
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691

# %%
from urlparse import urlparse
def get_domain(s):
    return '_'.join(urlparse(s).netloc.split('.')[-2:])
print get_domain('http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691')
# Out:
# rankingsandreviews_com

# %%
# Download links for each url. Store inlinks/outlinks for each page in original set.
from collections import defaultdict
import requests
import time
from urlparse import urlparse
from BeautifulSoup import BeautifulSoup

    
def crawl(toprocess, depth=2):
    """ Crawl pages from seed set."""
    processed = set()
    inlinks = defaultdict(lambda: set())   # url -> set of inlinks
    outlinks = defaultdict(lambda: set())  # url -> set of outlinks 

    for i in range(depth):  # depth to crawl
        toprocess -= processed
        new_urls = set()
        for url in toprocess:
            print 'url=', url
            domain = get_domain(url)
            soup = BeautifulSoup(requests.get(url).text)
            processed.add(url)
            links = set([clean_url(a['href']) for a in soup.findAll('a') if a.get('href') and
                                                                            a['href'][:5] == 'http:' and
                                                                            get_domain(a['href']) != domain])
            print 'found %d links' % len(links)
            outlinks[url] = links
            for link in links:
                inlinks[link].add(url)
            # Add links to be processed
            links = [l for l in links if l not in processed and l not in toprocess][:20]
            new_urls |= set(links)
        toprocess = new_urls
    return inlinks, outlinks
    
inlinks, outlinks = crawl(urls)
# Out:
# url= http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
# found 2 links
# url= http://www.engineering.uic.edu
# found 3 links
# url= http://web.iit.edu
# found 6 links
# url= http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# found 37 links
# url= http://travel.usnews.com/cruises
# found 3 links
# url= http://bestlawfirms.usnews.com/rankings.aspx
# found 6 links
# url= http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# found 8 links
# url= http://twitter.com/UICEngineering
# found 21 links
# url= http://money.usnews.com/funds/mutual-funds
# found 5 links
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# url= http://www.youtube.com/user/UICengineering
# found 1 links
# url= http://www.universitytechnologypark.com
# found 4 links
# url= http://health.usnews.com
# found 4 links
# url= http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# found 11 links
# url= http://www.iitri.org
# found 1 links
# url= http://mediakit.usnews.com/index.php
# found 1 links
# url= http://nces.ed.gov/collegenavigator/?s=IL
# found 3 links
# url= http://beonair.com/about
# found 2 links
# url= http://twitter.com/#!/usnewseducation
# found 0 links
# url= http://travel.usnews.com/Rankings
# found 8 links
# url= http://travel.usnews.com/Hotels
# found 8 links
# url= http://travel.usnews.com
# found 3 links
# url= http://www.iitmicrogrid.net
# found 0 links
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/awculott/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# url= http://www.flickr.com/photos/uic_engineering/sets
# found 7 links
# url= http://money.usnews.com/money/careers
# found 5 links
# url= http://www.usnews.com
# found 3 links
# url= http://www.kentlaw.edu
# found 20 links
# url= http://money.usnews.com/529s
# found 3 links
# url= http://health.usnews.com/doctors
# found 3 links
# url= http://health.usnews.com/best-nursing-homes
# found 3 links
# url= http://www.illinoistechathletics.com
# found 17 links
# url= http://health.usnews.com/health-news/best-hospitals
# found 6 links
# url= http://health.usnews.com/health-products
# found 4 links
# url= http://www.usnews.com/education/best-colleges/paying-for-college
# found 9 links
# url= http://www.usnews.com/rss/education
# found 0 links
# url= http://health.usnews.com/health-insurance
# found 4 links

# %%
urls = set(inlinks.keys() + outlinks.keys())
print '%d total urls' % len(urls)
# Out:
# 167 total urls

# %%
# Print outlinks.
for url in outlinks:
    if len(outlinks[url]) > 0:
        print '\n', url, '->\n', '\n'.join(outlinks[url])
# Out:
# http://travel.usnews.com/cruises ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com/education/best-colleges/paying-for-college ->
# http://www.usnewsuniversitydirectory.com/masters-mba.aspx
# http://www.usnewsuniversitydirectory.com/bachelors.aspx
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.usnewsuniversitydirectory.com/Colleges-Universities/financialaid/?mcid=53158
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://www.usnewsuniversitydirectory.com/certificates.aspx
# http://www.usnewsuniversitydirectory.com
# http://www.usnewsuniversitydirectory.com/associates.aspx
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://money.usnews.com/funds/mutual-funds ->
# http://www.interactivedata.com
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.morningstar.com/IntroPage.aspx
#
# http://twitter.com/UICEngineering ->
# http://t.co/IHS6wQJn53
# http://t.co/ot3qjGFxW5
# http://t.co/fTZJPTLz7Z
# http://t.co/XeBvC03gDZ
# http://t.co/oI7oAySmvZ
# http://t.co/BTVdVcTWbN
# http://t.co/LfqtxCqiW1
# http://t.co/fkADHybJVX
# http://t.co/QO23byb5jK
# http://t.co/Hw7YrdV7fy
# http://t.co/TNJqfncVl6
# http://t.co/d76QlyoXXm
# http://t.co/rpbLi1a27M
# http://t.co/0aXUtqPbBW
# http://t.co/GoeCMjyy9o
# http://t.co/krCmOjpXky
# http://t.co/0nkACtRozg
# http://t.co/vInl2DVjt9
# http://t.co/QC6GAkeEyI
# http://t.co/yFFo4Dm0Oi
# http://t.co/MwQmPtF0wg
#
# http://beonair.com/about ->
# http://www.facebook.com/ohiocenterforbroadcasting
# http://www.facebook.com/BeOnAirIllinois
#
# http://health.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 ->
# http://www.facebook.com/usnewsbestcolleges
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://trk.usnud.net/?a=14&oc=296&c=4240&m=17&s1=54096
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691/jobs
# http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-graduate-schools/illinois-institute-of-technology-145725
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://colleges.usnews.rankingsandreviews.com/best-colleges/illinois-institute-of-technology-145725/overall-rankings
# http://twitter.com/#!/usnewseducation
#
# http://www.iitri.org ->
# http://www.iubenda.com/privacy-policy/264605
#
# http://health.usnews.com/best-nursing-homes ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://nces.ed.gov/collegenavigator/?s=IL ->
# http://www.childstats.gov
# http://www.bls.gov/oco
# http://fedstats.sites.usa.gov
#
# http://travel.usnews.com/Hotels ->
# http://usnews.rankingsandreviews.com/cars-trucks
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17527855&agid=4755&c=4771&l=1&e=3&f=28970&av=4&g=b4a9c960c8&j=6&w=2281162&sig=02b773cfda168c6070f42577fa81b4e9
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=4817474&agid=4709&c=4725&l=2&e=3&f=28970&av=9&g=cb24743bad&j=6&w=84070&sig=a4ad8994da98f1a0f6ab6d8b8d918c24
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17594382&agid=4755&c=4771&l=3&e=3&f=28970&av=4&g=cde14b1a26&j=6&w=2502495&sig=4ce224ac6ef36070f2e0ac868b31dcc4
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17565052&agid=4999&c=5015&l=5&e=1&f=28970&av=241&g=cc7e087cad&j=6&sig=08b3bf0b9c59078d289f4684cbefef11
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=16049367&agid=4752&c=4768&l=4&e=5&f=28970&av=9&g=144d30902b&j=6&w=219444&sig=1c3c1ef4ac855784bf18a27395b7ec26
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://travel.usnews.com/Rankings ->
# http://usnews.rankingsandreviews.com/cars-trucks
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=17271758&agid=4999&c=5015&l=4&e=1&f=60864&av=241&g=d687dcff6e&j=6&sig=23757de6cadc4d0c513fcc2606ecc12c
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=16946148&agid=4999&c=5015&l=2&e=1&f=60864&av=241&g=706e3cfa4f&j=6&sig=a865e158a620700e47c0da26a0657b7d
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=6316090&agid=4704&c=4720&l=5&e=3&f=60864&av=9&g=a5c1ffa2bf&j=6&w=223120&sig=d9b728ceca4216ed2811c36715279d88
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=6679958&agid=4704&c=4720&l=3&e=3&f=60864&av=9&g=1eb9f138c7&j=6&w=284441&sig=d7bbcde21ef02790a07de92c412fa9ef
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=15900831&agid=4704&c=4720&l=1&e=3&f=60864&av=9&g=cb24743bad&j=6&w=123524&sig=cca3c965e9fb5b2ea903029452f20d89
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://travel.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.flickr.com/photos/uic_engineering/sets ->
# http://blog.flickr.net
# http://sports.yahoo.com
# http://everything.yahoo.com
# http://flickr.tumblr.com
# http://finance.yahoo.com
# http://shopping.yahoo.com
# http://news.yahoo.com
#
# http://money.usnews.com/money/careers ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://www.indeed.com
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.usnews.com ->
# http://usnews.rankingsandreviews.com/cars-trucks/rankings/used
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://www.kentlaw.edu ->
# http://twitter.com/ChicagoKentLaw
# http://www.dtc.bkstore.com
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4269&information_id=6623&type=&rss=rss
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4169&information_id=6339&type=&rss=rss
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A
# http://www.iit.edu/cdr
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=798&information_id=2550&type=&rss=rss
# http://instagram.com/chicagokentlaw
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4118&information_id=6227&type=&rss=rss
# http://www.facebook.com/ChicagoKentLaw
# http://www.iit.edu/about/department_sites.shtml
# http://www.youtube.com/ChicagoKentLaw
# http://blogs.kentlaw.iit.edu
# http://www.iit.edu
# http://calendar.kentlaw.iit.edu
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=800&information_id=2554&type=&rss=rss
# http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014
# http://www.iit.edu/directory/shuttlebus.html
# http://www.oyez.org
#
# http://money.usnews.com/529s ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://health.usnews.com/doctors ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://health.usnews.com/health-news/best-hospitals ->
# http://www.aha.org
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://twitter.com/#!/USNewsHealth
#
# http://health.usnews.com/health-products ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://usnews.rankingsandreviews.com/cars-trucks
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://mediakit.usnews.com/index.php ->
# http://usnews.rankingsandreviews.com/cars-trucks
#
# http://health.usnews.com/health-insurance ->
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
# http://www.ehealthinsurance.com/?allid=USN27889
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
#
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 ->
# http://thecollegejuice.com
# http://www.facultyenlight.com/?storeNbr=296
# http://www.bncollegejobs.com
# http://www.facebook.com/IITbookstore
# http://www.thecollegejuice.com
# http://forms.bncollegemail.com/email/form2.htm
# http://www.iit.edu
# http://www.barnesandnoble.com/include/copyright.asp
#
# http://www.engineering.uic.edu ->
# http://www.flickr.com/photos/uic_engineering/sets
# http://twitter.com/UICEngineering
# http://www.youtube.com/user/UICengineering
#
# http://www.youtube.com/user/UICengineering ->
# http://www.engr.uic.edu
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 ->
# http://travel.usnews.com/cruises
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/funds/mutual-funds
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://twitter.com/#!/usnewseducation
# http://travel.usnews.com/Rankings
# http://travel.usnews.com
# http://money.usnews.com/money/careers
# http://money.usnews.com/529s
# http://health.usnews.com/doctors
# http://www.usnews.com/rss/education
# http://health.usnews.com/health-news/best-hospitals
# http://health.usnews.com/health-products
# http://health.usnews.com/health-insurance
# http://bestlawfirms.usnews.com/rankings.aspx
# http://mediakit.usnews.com/index.php
# http://www.usnews.com
# http://money.usnews.com/financial-advisors
# http://health.usnews.com/best-diet
# http://www.usnews.com/education/best-colleges/applying
# http://money.usnews.com/funds/etfs
# http://www.facebook.com/usnewsbestcolleges
# http://money.usnews.com
# http://travel.usnews.com/Rankings/Travel-Rewards/hotel-rewards
# http://travel.usnews.com/Rankings/Travel-Rewards/airline-rewards
# http://www.linkedin.com/company/u.s.-news-&-world-report
# http://bestlawfirms.usnews.com
# http://www.usnews.com/products/features/home
# http://health.usnews.com/medicare
# http://iit.edu/undergrad_admission
# http://video.usnews.com
# http://money.usnews.com/money/retirement
# http://www.usnews.com/usnews/store/college_compass.htm?src=gauge&ref=/colleges/myfit-dashboard
# http://aftercollege.com
#
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago ->
# http://nces.ed.gov/collegenavigator/?s=IL
# http://beonair.com/about
#
# http://bestlawfirms.usnews.com/rankings.aspx ->
# http://plus.google.com/+usnewsworldreport
# http://usnews.rankingsandreviews.com/cars-trucks
# http://usnews.rankingsandreviews.com/cars-trucks/rankings
# http://www.facebook.com/usnewsandworldreport
# http://twitter.com/usnews
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars
#
# http://web.iit.edu ->
# http://www.iitmicrogrid.net
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.kentlaw.edu
# http://www.universitytechnologypark.com
# http://www.illinoistechathletics.com
# http://www.iitri.org
#
# http://www.universitytechnologypark.com ->
# http://www.nbia.org
# http://www.aurp.net/aurp-awards-of-excellence
# http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775
# http://www.aurp.net
#
# http://www.illinoistechathletics.com ->
# http://web.iit.edu/about/campus-locations
# http://www.theuscaa.com/landing/index
# http://www.adidas.com/us
# http://web.iit.edu
# http://admissions.iit.edu/undergraduate
# http://www.mlc-mwlc.org/landing/index
# http://admissions.iit.edu/undergraduate/apply
# http://www.ncaa.com
# http://admissions.iit.edu/undergraduate/programs
# http://www.d3sports.com/landing/index
# http://wcsphoto.zenfolio.com/f417637883
# http://www.collegecostcalculator.org/IIT
# http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education
# http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student
# http://www.prestosports.com
# http://admissions.iit.edu/undergraduate/visit
# http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student

# %%
# Print inlinks
for url in inlinks:
    if len(inlinks[url]) > 0:
        print '\n', url, '<-\n', '\n'.join(inlinks[url])
# Out:
# http://plus.google.com/+usnewsworldreport <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://t.co/XeBvC03gDZ <-
# http://twitter.com/UICEngineering
#
# http://www.theuscaa.com/landing/index <-
# http://www.illinoistechathletics.com
#
# http://www.iubenda.com/privacy-policy/264605 <-
# http://www.iitri.org
#
# http://forms.bncollegemail.com/email/form2.htm <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.prestosports.com <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/pages/University-Technology-Park-at-IIT/265227113561775 <-
# http://www.universitytechnologypark.com
#
# http://beonair.com/about <-
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
# http://health.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://twitter.com/usnews <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=15900831&agid=4704&c=4720&l=1&e=3&f=60864&av=9&g=cb24743bad&j=6&w=123524&sig=cca3c965e9fb5b2ea903029452f20d89 <-
# http://travel.usnews.com/Rankings
#
# http://t.co/krCmOjpXky <-
# http://twitter.com/UICEngineering
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/illinois-institute-of-technology-145725/overall-rankings <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.nxtbook.com/nxtbooks/chicagokent/viewbook2014 <-
# http://www.kentlaw.edu
#
# http://twitter.com/#!/usnewseducation <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnews.com/education/best-colleges/applying <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/fkADHybJVX <-
# http://twitter.com/UICEngineering
#
# http://t.co/Hw7YrdV7fy <-
# http://twitter.com/UICEngineering
#
# http://health.usnews.com/doctors <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://health.usnews.com/health-products <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://sports.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://t.co/BTVdVcTWbN <-
# http://twitter.com/UICEngineering
#
# http://maps.google.com/maps?q=565+West+Adams+Street,+Chicago,+IL+60661-3691+&hl=en&ll=41.879387,-87.642252&spn=0.010592,0.026157&sll=37.0625,-95.677068&sspn=48.287373,107.138672&vpsrc=0&hnear=565+W+Adams+St,+Chicago,+Illinois+60661&t=m&z=16&iwloc=A <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/money/retirement <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnewsuniversitydirectory.com/Colleges-Universities/financialaid/?mcid=53158 <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4269&information_id=6623&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://instagram.com/chicagokentlaw <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/financial-advisors <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://wcsphoto.zenfolio.com/f417637883 <-
# http://www.illinoistechathletics.com
#
# http://www.barnesandnoble.com/include/copyright.asp <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://finance.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://news.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://travel.usnews.com/Rankings/Travel-Rewards/hotel-rewards <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://travel.usnews.com/Rankings/Travel-Rewards/airline-rewards <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.linkedin.com/company/u.s.-news-&-world-report <-
# http://money.usnews.com/money/careers
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/health-news/best-hospitals
# http://health.usnews.com/health-products
#
# http://health.usnews.com/medicare <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4118&information_id=6227&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://www.nbia.org <-
# http://www.universitytechnologypark.com
#
# http://www.illinoistechathletics.com <-
# http://web.iit.edu
#
# http://www.ncaa.com <-
# http://www.illinoistechathletics.com
#
# http://www.oyez.org <-
# http://www.kentlaw.edu
#
# http://www.d3sports.com/landing/index <-
# http://www.illinoistechathletics.com
#
# http://calendar.kentlaw.iit.edu <-
# http://www.kentlaw.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17594382&agid=4755&c=4771&l=3&e=3&f=28970&av=4&g=cde14b1a26&j=6&w=2502495&sig=4ce224ac6ef36070f2e0ac868b31dcc4 <-
# http://travel.usnews.com/Hotels
#
# http://www.usnews.com/education/best-colleges/paying-for-college <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://twitter.com/UICEngineering <-
# http://www.engineering.uic.edu
#
# http://www.iitri.org <-
# http://web.iit.edu
#
# http://nces.ed.gov/collegenavigator/?s=IL <-
# http://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_Chicago
#
# http://travel.usnews.com/Hotels <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=800&information_id=2554&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://travel.usnews.com/Rankings <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.facultyenlight.com/?storeNbr=296 <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.usnewsuniversitydirectory.com/masters-mba.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://www.usnewsuniversitydirectory.com/certificates.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://www.iit.edu/cdr <-
# http://www.kentlaw.edu
#
# http://www.kentlaw.edu <-
# http://web.iit.edu
#
# http://usnews.rankingsandreviews.com/cars-trucks/rankings <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://www.usnews.com
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://fedstats.sites.usa.gov <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://mediakit.usnews.com/index.php <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.iit.edu/directory/shuttlebus.html <-
# http://www.kentlaw.edu
#
# http://health.usnews.com/health-insurance <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://thecollegejuice.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://flickr.tumblr.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://www.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.thecollegejuice.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.youtube.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=6679958&agid=4704&c=4720&l=3&e=3&f=60864&av=9&g=1eb9f138c7&j=6&w=284441&sig=d7bbcde21ef02790a07de92c412fa9ef <-
# http://travel.usnews.com/Rankings
#
# http://t.co/0aXUtqPbBW <-
# http://twitter.com/UICEngineering
#
# http://twitter.com/#!/USNewsHealth <-
# http://health.usnews.com/health-news/best-hospitals
#
# http://admissions.iit.edu/undergraduate/visit <-
# http://www.illinoistechathletics.com
#
# http://money.usnews.com/funds/etfs <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.facebook.com/usnewsbestcolleges <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://money.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.ehealthinsurance.com/?allid=USN27889 <-
# http://health.usnews.com/health-insurance
#
# http://iit.edu/undergrad_admission <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/oI7oAySmvZ <-
# http://twitter.com/UICEngineering
#
# http://t.co/ot3qjGFxW5 <-
# http://twitter.com/UICEngineering
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=4169&information_id=6339&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://admissions.iit.edu/undergraduate/finances/tuition-and-fees#financing-your-education <-
# http://www.illinoistechathletics.com
#
# http://www.usnews.com/usnews/store/college_compass.htm?src=gauge&ref=/colleges/myfit-dashboard <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.aurp.net <-
# http://www.universitytechnologypark.com
#
# http://blog.flickr.net <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://admissions.iit.edu/undergraduate <-
# http://www.illinoistechathletics.com
#
# http://calendar.kentlaw.iit.edu/EventList.aspx?view=EventDetails&eventidn=798&information_id=2550&type=&rss=rss <-
# http://www.kentlaw.edu
#
# http://everything.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets
#
# http://t.co/d76QlyoXXm <-
# http://twitter.com/UICEngineering
#
# http://t.co/GoeCMjyy9o <-
# http://twitter.com/UICEngineering
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=16049367&agid=4752&c=4768&l=4&e=5&f=28970&av=9&g=144d30902b&j=6&w=219444&sig=1c3c1ef4ac855784bf18a27395b7ec26 <-
# http://travel.usnews.com/Hotels
#
# http://www.iit.edu/about/department_sites.shtml <-
# http://www.kentlaw.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17527855&agid=4755&c=4771&l=1&e=3&f=28970&av=4&g=b4a9c960c8&j=6&w=2281162&sig=02b773cfda168c6070f42577fa81b4e9 <-
# http://travel.usnews.com/Hotels
#
# http://www.iitmicrogrid.net <-
# http://web.iit.edu
#
# http://www.flickr.com/photos/uic_engineering/sets <-
# http://www.engineering.uic.edu
#
# http://t.co/QO23byb5jK <-
# http://twitter.com/UICEngineering
#
# http://money.usnews.com/529s <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.usnewsuniversitydirectory.com/bachelors.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://health.usnews.com/health-news/best-hospitals <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.bncollegejobs.com <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.usnewsuniversitydirectory.com/associates.aspx <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://t.co/yFFo4Dm0Oi <-
# http://twitter.com/UICEngineering
#
# http://www.interactivedata.com <-
# http://money.usnews.com/funds/mutual-funds
#
# http://twitter.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://www.childstats.gov <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://www.iit.edu <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
# http://www.kentlaw.edu
#
# http://www.morningstar.com/IntroPage.aspx <-
# http://money.usnews.com/funds/mutual-funds
#
# http://www.youtube.com/user/UICengineering <-
# http://www.engineering.uic.edu
#
# http://t.co/rpbLi1a27M <-
# http://twitter.com/UICEngineering
#
# http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-graduate-schools/illinois-institute-of-technology-145725 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.usnewsuniversitydirectory.com <-
# http://www.usnews.com/education/best-colleges/paying-for-college
#
# http://health.usnews.com/best-diet <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://admissions.iit.edu/undergraduate/apply/apply-international-first-year-freshman-student <-
# http://www.illinoistechathletics.com
#
# http://t.co/vInl2DVjt9 <-
# http://twitter.com/UICEngineering
#
# http://t.co/MwQmPtF0wg <-
# http://twitter.com/UICEngineering
#
# http://t.co/IHS6wQJn53 <-
# http://twitter.com/UICEngineering
#
# http://usnews.rankingsandreviews.com/cars-trucks <-
# http://bestlawfirms.usnews.com/rankings.aspx
# http://travel.usnews.com/cruises
# http://travel.usnews.com
# http://travel.usnews.com/Rankings
# http://mediakit.usnews.com/index.php
# http://money.usnews.com/money/careers
# http://money.usnews.com/funds/mutual-funds
# http://www.usnews.com
# http://money.usnews.com/529s
# http://health.usnews.com
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
# http://health.usnews.com/doctors
# http://health.usnews.com/health-products
# http://www.usnews.com/education/best-colleges/paying-for-college
# http://health.usnews.com/best-nursing-homes
# http://travel.usnews.com/Hotels
# http://health.usnews.com/health-insurance
# http://health.usnews.com/health-news/best-hospitals
#
# http://www.facebook.com/usnewsandworldreport <-
# http://bestlawfirms.usnews.com/rankings.aspx
#
# http://www.usnews.com/products/features/home <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.bls.gov/oco <-
# http://nces.ed.gov/collegenavigator/?s=IL
#
# http://www.facebook.com/IITbookstore <-
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1
#
# http://www.facebook.com/BeOnAirIllinois <-
# http://beonair.com/about
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=17565052&agid=4999&c=5015&l=5&e=1&f=28970&av=241&g=cc7e087cad&j=6&sig=08b3bf0b9c59078d289f4684cbefef11 <-
# http://travel.usnews.com/Hotels
#
# http://video.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/LfqtxCqiW1 <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/apply/apply-international-visiting-and-exchange-student <-
# http://www.illinoistechathletics.com
#
# http://aftercollege.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://travel.usnews.com/cruises <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://usnews.rankingsandreviews.com/cars-trucks/rankings/used <-
# http://www.usnews.com
#
# http://trk.usnud.net/?a=14&oc=296&c=4240&m=17&s1=54096 <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://money.usnews.com/funds/mutual-funds <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/TNJqfncVl6 <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/programs <-
# http://www.illinoistechathletics.com
#
# http://health.usnews.com/best-nursing-homes <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://t.co/0nkACtRozg <-
# http://twitter.com/UICEngineering
#
# http://www.adidas.com/us <-
# http://www.illinoistechathletics.com
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=17271758&agid=4999&c=5015&l=4&e=1&f=60864&av=241&g=d687dcff6e&j=6&sig=23757de6cadc4d0c513fcc2606ecc12c <-
# http://travel.usnews.com/Rankings
#
# http://travel.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://blogs.kentlaw.iit.edu <-
# http://www.kentlaw.edu
#
# http://money.usnews.com/money/careers <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=6316090&agid=4704&c=4720&l=5&e=3&f=60864&av=9&g=a5c1ffa2bf&j=6&w=223120&sig=d9b728ceca4216ed2811c36715279d88 <-
# http://travel.usnews.com/Rankings
#
# http://www.usnews.com/rss/education <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://web.iit.edu/about/campus-locations <-
# http://www.illinoistechathletics.com
#
# http://www.dtc.bkstore.com <-
# http://www.kentlaw.edu
#
# http://www.aha.org <-
# http://health.usnews.com/health-news/best-hospitals
#
# http://iit.bncollege.com/webapp/wcs/stores/servlet/BNCBHomePage?storeId=45055&catalogId=10001&langId=-1 <-
# http://web.iit.edu
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=aLrpgOhdEeSPyjZg6C6xQA&cid=2079840&pid=70&d=34438&p=28&y=3&x=3&m=0&t=0&s=1001&aid=4817474&agid=4709&c=4725&l=2&e=3&f=28970&av=9&g=cb24743bad&j=6&w=84070&sig=a4ad8994da98f1a0f6ab6d8b8d918c24 <-
# http://travel.usnews.com/Hotels
#
# http://deals.bookingbuddy.com/delivery/click?ruuid=zMy9kOhdEeSPyjZg6C6xQA&cid=2710537&pid=70&d=34678&p=43699&y=3&x=3&m=0&t=0&s=1001&aid=16946148&agid=4999&c=5015&l=2&e=1&f=60864&av=241&g=706e3cfa4f&j=6&sig=a865e158a620700e47c0da26a0657b7d <-
# http://travel.usnews.com/Rankings
#
# http://t.co/QC6GAkeEyI <-
# http://twitter.com/UICEngineering
#
# http://admissions.iit.edu/undergraduate/apply <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/ChicagoKentLaw <-
# http://www.kentlaw.edu
#
# http://www.collegecostcalculator.org/IIT <-
# http://www.illinoistechathletics.com
#
# http://www.facebook.com/ohiocenterforbroadcasting <-
# http://beonair.com/about
#
# http://bestlawfirms.usnews.com/rankings.aspx <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://www.aurp.net/aurp-awards-of-excellence <-
# http://www.universitytechnologypark.com
#
# http://www.indeed.com <-
# http://money.usnews.com/money/careers
#
# http://t.co/fTZJPTLz7Z <-
# http://twitter.com/UICEngineering
#
# http://bestlawfirms.usnews.com <-
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691
#
# http://web.iit.edu <-
# http://www.illinoistechathletics.com
#
# http://www.universitytechnologypark.com <-
# http://web.iit.edu
#
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691/jobs <-
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725
#
# http://www.engr.uic.edu <-
# http://www.youtube.com/user/UICengineering
#
# http://www.linkedin.com/groups?gid=71469&sharedKey=2839B80CA393 <-
# http://www.kentlaw.edu
#
# http://www.mlc-mwlc.org/landing/index <-
# http://www.illinoistechathletics.com
#
# http://shopping.yahoo.com <-
# http://www.flickr.com/photos/uic_engineering/sets

# %%
# Initialize hubs and authorities scores and print.
hubs = dict([(u, 1.0) for u in urls])
authorities = dict([(u, 1.0) for u in urls])
def print_top(hubs, authorities):
    print 'Top hubs\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:5])
    print 'Top authorities\n', '\n'.join('%s %.6f' % (u[0], u[1]) for u in sorted(authorities.items(), key=lambda x: x[1], reverse=True)[:5])
    print

print_top(hubs, authorities)
# Out:
# Top hubs
# http://plus.google.com/+usnewsworldreport 1.000000
# http://t.co/XeBvC03gDZ 1.000000
# http://www.theuscaa.com/landing/index 1.000000
# http://www.iubenda.com/privacy-policy/264605 1.000000
# http://forms.bncollegemail.com/email/form2.htm 1.000000
# Top authorities
# http://plus.google.com/+usnewsworldreport 1.000000
# http://t.co/XeBvC03gDZ 1.000000
# http://www.theuscaa.com/landing/index 1.000000
# http://www.iubenda.com/privacy-policy/264605 1.000000
# http://forms.bncollegemail.com/email/form2.htm 1.000000

# %%
# Update hub and authority scores.
import math

def update(hubs, authorities, inlinks, outlinks):
    for u in authorities:
        authorities[u] += sum([hubs[inlink] for inlink in inlinks[u]])
    normalize(authorities)
    for u in hubs:
        hubs[u] += sum([authorities[outlink] for outlink in outlinks[u]])
    normalize(hubs)

def normalize(d):
    norm = math.sqrt(sum([v * v for v in d.values()]))
    for k in d:
        d[k] /= norm

# %%
update(hubs, authorities, inlinks, outlinks)
print_top(hubs, authorities)
# Out:
# Top hubs
# http://colleges.usnews.rankingsandreviews.com/best-colleges/iit-1691 0.179887
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.173991
# http://www.usnews.com/education/best-colleges/paying-for-college 0.157776
# http://health.usnews.com/health-news/best-hospitals 0.156302
# http://travel.usnews.com/Hotels 0.154828
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.463002
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.438633
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.414265
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.170580
# http://twitter.com/#!/usnewseducation 0.073106

# %%
for i in range(10):
    update(hubs, authorities, inlinks, outlinks)
    print_top(hubs, authorities)
# Out:
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.287845
# http://health.usnews.com/health-news/best-hospitals 0.250861
# http://money.usnews.com/money/careers 0.245847
# http://www.usnews.com/education/best-colleges/paying-for-college 0.244229
# http://health.usnews.com 0.240965
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.533633
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.513949
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.489123
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.197935
# http://twitter.com/#!/usnewseducation 0.074467
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.295771
# http://health.usnews.com/health-news/best-hospitals 0.257815
# http://money.usnews.com/money/careers 0.252892
# http://www.usnews.com/education/best-colleges/paying-for-college 0.248194
# http://health.usnews.com 0.248148
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.549263
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.537147
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.515466
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.208226
# http://twitter.com/#!/usnewseducation 0.073633
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.297210
# http://health.usnews.com/health-news/best-hospitals 0.259856
# http://money.usnews.com/money/careers 0.254930
# http://health.usnews.com 0.250187
# http://health.usnews.com/health-products 0.250187
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.554639
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.544004
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.522986
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.207909
# http://twitter.com/#!/usnewseducation 0.070239
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.297238
# http://health.usnews.com/health-news/best-hospitals 0.260730
# http://money.usnews.com/money/careers 0.255785
# http://health.usnews.com 0.251025
# http://health.usnews.com/health-products 0.251025
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.557691
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.547273
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.526309
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.205748
# http://twitter.com/#!/usnewseducation 0.067037
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296925
# http://health.usnews.com/health-news/best-hospitals 0.261188
# http://money.usnews.com/money/careers 0.256231
# http://www.usnews.com/education/best-colleges/paying-for-college 0.251684
# http://health.usnews.com 0.251458
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.559661
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.549245
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.528228
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.203588
# http://twitter.com/#!/usnewseducation 0.064442
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296571
# http://health.usnews.com/health-news/best-hospitals 0.261463
# http://money.usnews.com/money/careers 0.256498
# http://www.usnews.com/education/best-colleges/paying-for-college 0.252278
# http://health.usnews.com 0.251718
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.561008
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.550568
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.529492
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.201794
# http://twitter.com/#!/usnewseducation 0.062424
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296257
# http://health.usnews.com/health-news/best-hospitals 0.261641
# http://money.usnews.com/money/careers 0.256671
# http://www.usnews.com/education/best-colleges/paying-for-college 0.252714
# http://health.usnews.com 0.251887
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.561960
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.551498
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.530374
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.200382
# http://twitter.com/#!/usnewseducation 0.060877
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.296000
# http://health.usnews.com/health-news/best-hospitals 0.261762
# http://money.usnews.com/money/careers 0.256789
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253034
# http://health.usnews.com 0.252002
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.562646
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.552166
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.531007
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.199293
# http://twitter.com/#!/usnewseducation 0.059698
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.295796
# http://health.usnews.com/health-news/best-hospitals 0.261847
# http://money.usnews.com/money/careers 0.256871
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253271
# http://health.usnews.com 0.252082
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.563145
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.552652
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.531467
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.198459
# http://twitter.com/#!/usnewseducation 0.058803
#
# Top hubs
# http://www.usnews.com/education/online-education/illinois-institute-of-technology-145725 0.295637
# http://health.usnews.com/health-news/best-hospitals 0.261907
# http://money.usnews.com/money/careers 0.256930
# http://www.usnews.com/education/best-colleges/paying-for-college 0.253447
# http://health.usnews.com 0.252139
# Top authorities
# http://usnews.rankingsandreviews.com/cars-trucks 0.563513
# http://usnews.rankingsandreviews.com/cars-trucks/rankings 0.553010
# http://usnews.rankingsandreviews.com/cars-trucks/used-cars 0.531806
# http://www.linkedin.com/company/u.s.-news-&-world-report 0.197824
# http://twitter.com/#!/usnewseducation 0.058124

# %% [markdown]
# ## Expanding the set of urls
#
# - How does restricting to only 20 links from each url limit these results?
# - For a given query, begin with the *root* set of the top $k$ matching documents.
# - Expand the set to include all forward and backward links from the root.
#
#
# When would this help?
